# %% [markdown]
# <h1>The Previous One</h1>

# %%
from flask import Flask, render_template, jsonify
import subprocess

app = Flask(__name__)

def get_graph_data(script_name):
    try:
        subprocess.check_output(['jupyter', 'nbconvert', '--to', 'script', f'{script_name}.ipynb'])
        result = subprocess.check_output(['python', f'{script_name}.py'], text=True)
        return result.strip(), 200, {'Content-Type': 'application/json'}
    except subprocess.CalledProcessError as e:
        return jsonify({'error': e.stderr}), 500
    except Exception as e:
        return jsonify({'error': str(e)}), 500

@app.route('/')
def home():
    return render_template('menu.html')

@app.route('/graph_data1')
def graph_data1():
    return get_graph_data('graph1')

@app.route('/graph_data2')
def graph_data2():
    return get_graph_data('graph2')

@app.route('/graph_data3')
def graph_data3():
    return get_graph_data('graph3')

@app.route('/graph_data4')
def graph_data4():
    return get_graph_data('graph4')

@app.route('/graph_data5')
def graph_data5():
    return get_graph_data('graph5')

@app.route('/graph_data6')
def graph_data6():
    return get_graph_data('graph6')

@app.route('/graph1')
def graph1():
    return render_template('indexG1.html')

@app.route('/graph2')
def graph2():
    return render_template('indexG2.html')

@app.route('/graph3')
def graph3():
    return render_template('indexG3.html')

@app.route('/graph4')
def graph4():
    return render_template('indexG4.html')

@app.route('/graph5')
def graph5():
    return render_template('indexG5.html')

@app.route('/graph6')
def graph6():
    return render_template('indexG6.html')

if __name__ == '__main__':
    app.run()

# %% [markdown]
# <h1>Now Optimizing</h1>

# %%
from flask import Flask, render_template, jsonify
import subprocess

app = Flask(__name__)

def get_graph_data(script_name):
    try:
        result = subprocess.check_output(['python', f'{script_name}.py'], text=True)
        return jsonify(result.strip()), 200, {'Content-Type': 'application/json'}
    except subprocess.CalledProcessError as e:
        return jsonify({'error': e.stderr}), 500
    except Exception as e:
        return jsonify({'error': str(e)}), 500

@app.route('/')
def home():
    return render_template('menu.html')

@app.route('/graph_data1')
def graph_data1():
    return get_graph_data('graph1')

@app.route('/graph_data2')
def graph_data2():
    return get_graph_data('graph2')

@app.route('/graph_data3')
def graph_data3():
    return get_graph_data('graph3')

@app.route('/graph_data4')
def graph_data4():
    return get_graph_data('graph4')

@app.route('/graph_data5')
def graph_data5():
    return get_graph_data('graph5')

@app.route('/graph_data6')
def graph_data6():
    return get_graph_data('graph6')

@app.route('/graph1')
def graph1():
    return render_template('indexG1.html')

@app.route('/graph2')
def graph2():
    return render_template('indexG2.html')

@app.route('/graph3')
def graph3():
    return render_template('indexG3.html')

@app.route('/graph4')
def graph4():
    return render_template('indexG4.html')

@app.route('/graph5')
def graph5():
    return render_template('indexG5.html')

@app.route('/graph6')
def graph6():
    return render_template('indexG6.html')

if __name__ == '__main__':
    app.run()

# %% [markdown]
# <h1>Adding a login page</h1>

# %%
from flask import Flask, render_template, jsonify, request
import psycopg2
import subprocess

app = Flask(__name__)

def get_graph_data(script_name):
    try:
        result = subprocess.check_output(['python', f'{script_name}.py'], text=True)
        return jsonify(result.strip()), 200, {'Content-Type': 'application/json'}
    except subprocess.CalledProcessError as e:
        return jsonify({'error': e.stderr}), 500
    except Exception as e:
        return jsonify({'error': str(e)}), 500

@app.route('/menuAdmin')
def menuAdmin():
    return render_template('menu.html')

@app.route('/menuUser')
def menuUser():
    return render_template('menu.html')

@app.route('/')
def home():
    return render_template('landingPage.html')

@app.route('/admin')
def admin():
    return render_template('admin.html')

@app.route('/user')
def user():
    return render_template('user.html')

@app.route('/graph_data1')
def graph_data1():
    return get_graph_data('graph1')

@app.route('/graph_data2')
def graph_data2():
    return get_graph_data('graph2')

@app.route('/graph_data3')
def graph_data3():
    return get_graph_data('graph3')

@app.route('/graph_data4')
def graph_data4():
    return get_graph_data('graph4')

@app.route('/graph_data5')
def graph_data5():
    return get_graph_data('graph5')

@app.route('/graph_data6')
def graph_data6():
    return get_graph_data('graph6')

@app.route('/graph1')
def graph1():
    return render_template('indexG1.html')

@app.route('/graph2')
def graph2():
    return render_template('indexG2.html')

@app.route('/graph3')
def graph3():
    return render_template('indexG3.html')

@app.route('/graph4')
def graph4():
    return render_template('indexG4.html')

@app.route('/graph5')
def graph5():
    return render_template('indexG5.html')

@app.route('/graph6')
def graph6():
    return render_template('indexG6.html')

@app.route('/validate', methods=['POST'])
def validate():
    username = request.form['username']

    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )

    cursor = conn.cursor()
    cursor.execute(f"SELECT count(name_) FROM userrole JOIN usermode ON userrole.userid = usermode.userid WHERE roleid = 1 and name_ = '{username}'")
    result = cursor.fetchone()[0]

    if result > 0:
        return "<script>alert('Access granted!'); window.location.href='/menuAdmin';</script>"
    else:
        return "<script>alert('Access denied!'); window.location.href='/';</script>"

    
@app.route('/validate2', methods=['POST'])
def validate2():
    username = request.form['username']

    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )

    cursor = conn.cursor()
    cursor.execute(f"SELECT count(name_) FROM userrole JOIN usermode ON userrole.userid = usermode.userid WHERE roleid = 2 and name_ = '{username}'")
    result = cursor.fetchone()[0]

    if result > 0:
        return """
        <script>
            alert('Access granted!');
            window.location.href = '/menuUser';
        </script>
        """
    else:
        return """
        <script>
            alert('Access denied!');
            window.location.href = '/';
        </script>
        """    


if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template, jsonify, request
import psycopg2
import subprocess

app = Flask(__name__)

def get_graph_data(script_name, quarter=''):
    try:
        result = subprocess.check_output(['python', f'{script_name}.py', quarter], text=True)
        return jsonify(result.strip()), 200, {'Content-Type': 'application/json'}
    except subprocess.CalledProcessError as e:
        return jsonify({'error': e.stderr}), 500
    except Exception as e:
        return jsonify({'error': str(e)}), 500

@app.route('/menuAdmin')
def menuAdmin():
    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )
    cursor = conn.cursor()
    query = "SELECT menu.menudescription FROM rolemenu JOIN menu ON rolemenu.menuid=menu.menuid WHERE status='true' AND roleid=1"
    cursor.execute(query)
    results = cursor.fetchall()
    cursor.close()
    conn.close()
    return render_template('menuAdmin.html', results=results)

@app.route('/menuUser')
def menuUser():
    
    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )
    cursor = conn.cursor()
    query = "SELECT menu.menudescription FROM rolemenu JOIN menu ON rolemenu.menuid=menu.menuid WHERE status='true' AND roleid=2"
    cursor.execute(query)
    results = cursor.fetchall()
    cursor.close()
    conn.close()
    return render_template('menuUser.html', results=results)

@app.route('/')
def home():
    return render_template('landingPage.html')

@app.route('/admin')
def admin():
    return render_template('admin.html')

@app.route('/user')
def user():
    return render_template('user.html')

@app.route('/graph_data1', methods=['GET'])
def graph_data1():
    quarter = request.args.get('quarter', '')  # Get the value of the 'quarter' query parameter

    try:
        result = subprocess.check_output(['python', 'graph1.py', quarter], text=True)
        return jsonify(result.strip()), 200
    except subprocess.CalledProcessError as e:
        return str(e.output), 500

@app.route('/graph_data2')
def graph_data2():
    return get_graph_data('graph2')

@app.route('/graph_data3')
def graph_data3():
    return get_graph_data('graph3')

@app.route('/graph_data4')
def graph_data4():
    return get_graph_data('graph4')

@app.route('/graph_data5')
def graph_data5():
    return get_graph_data('graph5')

@app.route('/graph_data6')
def graph_data6():
    return get_graph_data('graph6')

@app.route('/graph1')
def graph1():
    return render_template('indexG1 - Copy.html')

@app.route('/graph2')
def graph2():
    return render_template('indexG2.html')

@app.route('/graph3')
def graph3():
    return render_template('indexG3.html')

@app.route('/graph4')
def graph4():
    return render_template('indexG4.html')

@app.route('/graph5')
def graph5():
    return render_template('indexG5.html')

@app.route('/graph6')
def graph6():
    return render_template('indexG6.html')

@app.route('/validate', methods=['POST'])
def validate():
    username = request.form['username']

    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )

    cursor = conn.cursor()
    cursor.execute(f"SELECT count(name_) FROM userrole JOIN usermode ON userrole.userid = usermode.userid WHERE roleid = 1 and name_ = '{username}'")
    result = cursor.fetchone()[0]

    if result > 0:
        return "<script>alert('Access granted!'); window.location.href='/menuAdmin';</script>"
    else:
        return "<script>alert('Access denied!'); window.location.href='/';</script>"

    
@app.route('/validate2', methods=['POST'])
def validate2():
    username = request.form['username']

    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )

    cursor = conn.cursor()
    cursor.execute(f"SELECT count(name_) FROM userrole JOIN usermode ON userrole.userid = usermode.userid WHERE roleid = 2 and name_ = '{username}'")
    result = cursor.fetchone()[0]

    if result > 0:
        return """
        <script>
            alert('Access granted!');
            window.location.href = '/menuUser';
        </script>
        """
    else:
        return """
        <script>
            alert('Access denied!');
            window.location.href = '/';
        </script>
        """    

if __name__ == '__main__':
    app.run()

# %% [markdown]
# <h1>ADDING QUARTELY BUTTONS</h1>

# %%
from flask import Flask, render_template, jsonify, request
import psycopg2
import subprocess

app = Flask(__name__)

def get_graph_data(script_name):
    try:
        result = subprocess.check_output(['python', f'{script_name}.py'], text=True)
        return jsonify(result.strip()), 200, {'Content-Type': 'application/json'}
    except subprocess.CalledProcessError as e:
        return jsonify({'error': e.stderr}), 500
    except Exception as e:
        return jsonify({'error': str(e)}), 500

@app.route('/menuAdmin')
def menuAdmin():
    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )
    cursor = conn.cursor()
    query = "SELECT menu.menudescription FROM rolemenu JOIN menu ON rolemenu.menuid=menu.menuid WHERE status='true' AND roleid=1"
    cursor.execute(query)
    results = cursor.fetchall()
    cursor.close()
    conn.close()
    return render_template('menuAdmin.html', results=results)

@app.route('/menuUser')
def menuUser():
    
    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )
    cursor = conn.cursor()
    query = "SELECT menu.menudescription FROM rolemenu JOIN menu ON rolemenu.menuid=menu.menuid WHERE status='true' AND roleid=2"
    cursor.execute(query)
    results = cursor.fetchall()
    cursor.close()
    conn.close()
    return render_template('menuUser.html', results=results)

@app.route('/')
def home():
    return render_template('landingPage.html')

@app.route('/admin')
def admin():
    return render_template('admin.html')

@app.route('/user')
def user():
    return render_template('user.html')

@app.route('/graph_data1', methods=['GET'])
def graph_data1():
    quarter = request.args.get('quarter', '')  # Get the value of the 'quarter' query parameter

    try:
        result = subprocess.check_output(['python', 'graph1.py', quarter], text=True)
        return jsonify(result.strip()), 200
    except subprocess.CalledProcessError as e:
        return str(e.output), 500

@app.route('/graph_data2')
def graph_data2():
    return get_graph_data('graph2')

@app.route('/graph_data3')
def graph_data3():
    return get_graph_data('graph3')

@app.route('/graph_data4')
def graph_data4():
    return get_graph_data('graph4')

@app.route('/graph_data5')
def graph_data5():
    return get_graph_data('graph5')

@app.route('/graph_data6')
def graph_data6():
    return get_graph_data('graph6')

@app.route('/graph1')
def graph1():
    return render_template('indexG1.html')

@app.route('/graph2')
def graph2():
    return render_template('indexG2.html')

@app.route('/graph3')
def graph3():
    return render_template('indexG3.html')

@app.route('/graph4')
def graph4():
    return render_template('indexG4.html')

@app.route('/graph5')
def graph5():
    return render_template('indexG5.html')

@app.route('/graph6')
def graph6():
    return render_template('indexG6.html')

@app.route('/validate', methods=['POST'])
def validate():
    username = request.form['username']

    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )

    cursor = conn.cursor()
    cursor.execute(f"SELECT count(name_) FROM userrole JOIN usermode ON userrole.userid = usermode.userid WHERE roleid = 1 and name_ = '{username}'")
    result = cursor.fetchone()[0]

    if result > 0:
        return "<script>alert('Access granted!'); window.location.href='/menuAdmin';</script>"
    else:
        return "<script>alert('Access denied!'); window.location.href='/';</script>"

    
@app.route('/validate2', methods=['POST'])
def validate2():
    username = request.form['username']

    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )

    cursor = conn.cursor()
    cursor.execute(f"SELECT count(name_) FROM userrole JOIN usermode ON userrole.userid = usermode.userid WHERE roleid = 2 and name_ = '{username}'")
    result = cursor.fetchone()[0]

    if result > 0:
        return """
        <script>
            alert('Access granted!');
            window.location.href = '/menuUser';
        </script>
        """
    else:
        return """
        <script>
            alert('Access denied!');
            window.location.href = '/';
        </script>
        """    

if __name__ == '__main__':
    app.run()

# %% [markdown]
# <h1>Adding the buttons (Quarterly) now</h1>

# %%
from flask import Flask, render_template, jsonify, request
import subprocess

app = Flask(__name__)

@app.route('/')
def index():
    return render_template('indexG1.html')

@app.route('/graph_data1', methods=['GET'])
def graph_data1():
    quarter = request.args.get('quarter', '')  # Get the value of the 'quarter' query parameter

    try:
        result = subprocess.check_output(['python', 'graph1.py', quarter], text=True)
        return jsonify(result.strip()), 200
    except subprocess.CalledProcessError as e:
        return str(e.output), 500

if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template, jsonify, request
import psycopg2
import subprocess

app = Flask(__name__)


@app.route('/menuAdmin')
def menuAdmin():
    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )
    cursor = conn.cursor()
    query = "SELECT menu.menudescription FROM rolemenu JOIN menu ON rolemenu.menuid=menu.menuid WHERE status='true' AND roleid=1"
    cursor.execute(query)
    results = cursor.fetchall()
    cursor.close()
    conn.close()
    return render_template('menuAdmin.html', results=results)

@app.route('/menuUser')
def menuUser():
    
    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )
    cursor = conn.cursor()
    query = "SELECT menu.menudescription FROM rolemenu JOIN menu ON rolemenu.menuid=menu.menuid WHERE status='true' AND roleid=2"
    cursor.execute(query)
    results = cursor.fetchall()
    cursor.close()
    conn.close()
    return render_template('menuUser.html', results=results)

@app.route('/')
def home():
    return render_template('landingPage.html')

@app.route('/admin')
def admin():
    return render_template('admin.html')

@app.route('/user')
def user():
    return render_template('user.html')

@app.route('/graph_data1', methods=['GET'])
def graph_data1():
    quarter = request.args.get('quarter', '')  # Get the value of the 'quarter' query parameter

    try:
        result = subprocess.check_output(['python', 'graph1.py', quarter], text=True)
        return jsonify(result.strip()), 200
    except subprocess.CalledProcessError as e:
        return str(e.output), 500

@app.route('/graph_data2', methods=['GET'])
def graph_data2():
    quarter = request.args.get('quarter', '')  # Get the value of the 'quarter' query parameter

    try:
        result = subprocess.check_output(['python', 'graph2.py', quarter], text=True)
        return jsonify(result.strip()), 200
    except subprocess.CalledProcessError as e:
        return str(e.output), 500

@app.route('/graph_data3', methods=['GET'])
def graph_data3():
    quarter = request.args.get('quarter', '')  # Get the value of the 'quarter' query parameter

    try:
        result = subprocess.check_output(['python', 'graph3.py', quarter], text=True)
        return jsonify(result.strip()), 200
    except subprocess.CalledProcessError as e:
        return str(e.output), 500

@app.route('/graph_data4', methods=['GET'])
def graph_data4():
    quarter = request.args.get('quarter', '')  # Get the value of the 'quarter' query parameter

    try:
        result = subprocess.check_output(['python', 'graph4.py', quarter], text=True)
        return jsonify(result.strip()), 200
    except subprocess.CalledProcessError as e:
        return str(e.output), 500

@app.route('/graph_data5', methods=['GET'])
def graph_data5():
    quarter = request.args.get('quarter', '')  # Get the value of the 'quarter' query parameter

    try:
        result = subprocess.check_output(['python', 'graph5.py', quarter], text=True)
        return jsonify(result.strip()), 200
    except subprocess.CalledProcessError as e:
        return str(e.output), 500

@app.route('/graph_data6', methods=['GET'])
def graph_data6():
    quarter = request.args.get('quarter', '')  # Get the value of the 'quarter' query parameter

    try:
        result = subprocess.check_output(['python', 'graph6.py', quarter], text=True)
        return jsonify(result.strip()), 200
    except subprocess.CalledProcessError as e:
        return str(e.output), 500

@app.route('/graph1')
def graph1():
    return render_template('indexG1 - Copy.html')

@app.route('/graph2')
def graph2():
    return render_template('indexG2.html')

@app.route('/graph3')
def graph3():
    return render_template('indexG3.html')

@app.route('/graph4')
def graph4():
    return render_template('indexG4.html')

@app.route('/graph5')
def graph5():
    return render_template('indexG5.html')

@app.route('/graph6')
def graph6():
    return render_template('indexG6.html')

@app.route('/validate', methods=['POST'])
def validate():
    username = request.form['username']

    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )

    cursor = conn.cursor()
    cursor.execute(f"SELECT count(name_) FROM userrole JOIN usermode ON userrole.userid = usermode.userid WHERE roleid = 1 and name_ = '{username}'")
    result = cursor.fetchone()[0]

    if result > 0:
        return "<script>alert('Access granted!'); window.location.href='/menuAdmin';</script>"
    else:
        return "<script>alert('Access denied!'); window.location.href='/';</script>"

    
@app.route('/validate2', methods=['POST'])
def validate2():
    username = request.form['username']

    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )

    cursor = conn.cursor()
    cursor.execute(f"SELECT count(name_) FROM userrole JOIN usermode ON userrole.userid = usermode.userid WHERE roleid = 2 and name_ = '{username}'")
    result = cursor.fetchone()[0]

    if result > 0:
        return """
        <script>
            alert('Access granted!');
            window.location.href = '/menuUser';
        </script>
        """
    else:
        return """
        <script>
            alert('Access denied!');
            window.location.href = '/';
        </script>
        """    

if __name__ == '__main__':
    app.run()

# %% [markdown]
# <h1>Now adding Better CSS</h1>

# %%
from flask import Flask, render_template, jsonify, request
import psycopg2
import subprocess

app = Flask(__name__)


@app.route('/menuAdmin')
def menuAdmin():
    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )
    cursor = conn.cursor()
    query = "SELECT menu.menudescription FROM rolemenu JOIN menu ON rolemenu.menuid=menu.menuid WHERE status='true' AND roleid=1"
    cursor.execute(query)
    results = cursor.fetchall()
    cursor.close()
    conn.close()
    return render_template('menuAdmin.html', results=results)

@app.route('/menuUser')
def menuUser():
    
    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )
    cursor = conn.cursor()
    query = "SELECT menu.menudescription FROM rolemenu JOIN menu ON rolemenu.menuid=menu.menuid WHERE status='true' AND roleid=2"
    cursor.execute(query)
    results = cursor.fetchall()
    cursor.close()
    conn.close()
    return render_template('menuUser.html', results=results)

@app.route('/')
def home():
    return render_template('landingPage.html')

@app.route('/admin')
def admin():
    return render_template('admin.html')

@app.route('/user')
def user():
    return render_template('user.html')

@app.route('/graph_data1', methods=['GET'])
def graph_data1():
    quarter = request.args.get('quarter', '')  # Get the value of the 'quarter' query parameter

    try:
        result = subprocess.check_output(['python', 'graph1.py', quarter], text=True)
        return jsonify(result.strip()), 200
    except subprocess.CalledProcessError as e:
        return str(e.output), 500

@app.route('/graph_data2', methods=['GET'])
def graph_data2():
    quarter = request.args.get('quarter', '')  # Get the value of the 'quarter' query parameter

    try:
        result = subprocess.check_output(['python', 'graph2.py', quarter], text=True)
        return jsonify(result.strip()), 200
    except subprocess.CalledProcessError as e:
        return str(e.output), 500

@app.route('/graph_data3', methods=['GET'])
def graph_data3():
    quarter = request.args.get('quarter', '')  # Get the value of the 'quarter' query parameter

    try:
        result = subprocess.check_output(['python', 'graph3.py', quarter], text=True)
        return jsonify(result.strip()), 200
    except subprocess.CalledProcessError as e:
        return str(e.output), 500

@app.route('/graph_data4', methods=['GET'])
def graph_data4():
    quarter = request.args.get('quarter', '')  # Get the value of the 'quarter' query parameter

    try:
        result = subprocess.check_output(['python', 'graph4.py', quarter], text=True)
        return jsonify(result.strip()), 200
    except subprocess.CalledProcessError as e:
        return str(e.output), 500

@app.route('/graph_data5', methods=['GET'])
def graph_data5():
    quarter = request.args.get('quarter', '')  # Get the value of the 'quarter' query parameter

    try:
        result = subprocess.check_output(['python', 'graph5.py', quarter], text=True)
        return jsonify(result.strip()), 200
    except subprocess.CalledProcessError as e:
        return str(e.output), 500

@app.route('/graph_data6', methods=['GET'])
def graph_data6():
    quarter = request.args.get('quarter', '')  # Get the value of the 'quarter' query parameter

    try:
        result = subprocess.check_output(['python', 'graph6.py', quarter], text=True)
        return jsonify(result.strip()), 200
    except subprocess.CalledProcessError as e:
        return str(e.output), 500

@app.route('/graph1')
def graph1():
    return render_template('indexG1.html')

@app.route('/graph2')
def graph2():
    return render_template('indexG2.html')

@app.route('/graph3')
def graph3():
    return render_template('indexG3.html')

@app.route('/graph4')
def graph4():
    return render_template('indexG4.html')

@app.route('/graph5')
def graph5():
    return render_template('indexG5.html')

@app.route('/graph6')
def graph6():
    return render_template('indexG6.html')

@app.route('/validate', methods=['POST'])
def validate():
    username = request.form['username']

    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )

    cursor = conn.cursor()
    cursor.execute(f"SELECT count(name_) FROM userrole JOIN usermode ON userrole.userid = usermode.userid WHERE roleid = 1 and name_ = '{username}'")
    result = cursor.fetchone()[0]

    if result > 0:
        return "<script>window.location.href='/menuAdmin';</script>"
    else:
        return "<script>alert('Access denied!'); window.location.href='/';</script>"

    
@app.route('/validate2', methods=['POST'])
def validate2():
    username = request.form['username']

    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )

    cursor = conn.cursor()
    cursor.execute(f"SELECT count(name_) FROM userrole JOIN usermode ON userrole.userid = usermode.userid WHERE roleid = 2 and name_ = '{username}'")
    result = cursor.fetchone()[0]

    if result > 0:
        return """
        <script>
            window.location.href = '/menuUser';
        </script>
        """
    else:
        return """
        <script>
            alert('Access denied!');
            window.location.href = '/';
        </script>
        """    

if __name__ == '__main__':
    app.run()

# %% [markdown]
# <h1>Adding in-graph options to change Type of graph</h1>

# %%
from flask import Flask, render_template, jsonify, request
import psycopg2
import subprocess

app = Flask(__name__)

number = None

@app.route('/menuAdmin')
def menuAdmin():
    global number
    number = 1

    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )
    cursor = conn.cursor()
    query = "SELECT menu.menudescription FROM rolemenu JOIN menu ON rolemenu.menuid=menu.menuid WHERE status='true' AND roleid=1"
    cursor.execute(query)
    results = cursor.fetchall()
    cursor.close()
    conn.close()

    return render_template('menuAdmin.html', results=results)

@app.route('/menuUser')
def menuUser():
    global number
    number = 2

    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )
    cursor = conn.cursor()
    query = "SELECT rolemenu.menuid, menu.menudescription FROM rolemenu JOIN menu ON rolemenu.menuid = menu.menuid WHERE menu.status = 'true' AND rolemenu.roleid = 2;"
    cursor.execute(query)
    results = cursor.fetchall()
    cursor.close()
    conn.close()

    return render_template('menuUser.html', results=results)


@app.route('/')
def home():
    return render_template('landingPage.html')

@app.route('/admin')
def admin():
    return render_template('admin.html')

@app.route('/user')
def user():
    return render_template('user.html')

@app.route('/graph_data1', methods=['GET'])
def graph_data1():
    quarter = request.args.get('quarter', '')  # Get the value of the 'quarter' query parameter

    try:
        result = subprocess.check_output(['python', 'graph1.py', quarter], text=True)
        return jsonify(result.strip()), 200
    except subprocess.CalledProcessError as e:
        return str(e.output), 500

@app.route('/graph_data2', methods=['GET'])
def graph_data2():
    quarter = request.args.get('quarter', '')  # Get the value of the 'quarter' query parameter

    try:
        result = subprocess.check_output(['python', 'graph2.py', quarter], text=True)
        return jsonify(result.strip()), 200
    except subprocess.CalledProcessError as e:
        return str(e.output), 500

@app.route('/graph_data3', methods=['GET'])
def graph_data3():
    quarter = request.args.get('quarter', '')  # Get the value of the 'quarter' query parameter

    try:
        result = subprocess.check_output(['python', 'graph3.py', quarter], text=True)
        return jsonify(result.strip()), 200
    except subprocess.CalledProcessError as e:
        return str(e.output), 500

@app.route('/graph_data4', methods=['GET'])
def graph_data4():
    quarter = request.args.get('quarter', '')  # Get the value of the 'quarter' query parameter

    try:
        result = subprocess.check_output(['python', 'graph4.py', quarter], text=True)
        return jsonify(result.strip()), 200
    except subprocess.CalledProcessError as e:
        return str(e.output), 500

@app.route('/graph_data5', methods=['GET'])
def graph_data5():
    quarter = request.args.get('quarter', '')  # Get the value of the 'quarter' query parameter

    try:
        result = subprocess.check_output(['python', 'graph5.py', quarter], text=True)
        return jsonify(result.strip()), 200
    except subprocess.CalledProcessError as e:
        return str(e.output), 500

@app.route('/graph_data6', methods=['GET'])
def graph_data6():
    quarter = request.args.get('quarter', '')  # Get the value of the 'quarter' query parameter

    try:
        result = subprocess.check_output(['python', 'graph6.py', quarter], text=True)
        return jsonify(result.strip()), 200
    except subprocess.CalledProcessError as e:
        return str(e.output), 500

@app.route('/graph1')
def graph1():
    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )
    cursor = conn.cursor()
    query = f"SELECT rolemenu.menuid, menu.menudescription FROM rolemenu JOIN menu ON rolemenu.menuid = menu.menuid WHERE menu.status = 'true' AND rolemenu.roleid = {number}"

    cursor.execute(query)
    results = cursor.fetchall()
    cursor.close()
    conn.close()
    return render_template('indexG1.html', results=results, number = number)


@app.route('/graph2')
def graph2():
    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )
    cursor = conn.cursor()
    query = f"SELECT rolemenu.menuid, menu.menudescription FROM rolemenu JOIN menu ON rolemenu.menuid = menu.menuid WHERE menu.status = 'true' AND rolemenu.roleid = {number}"

    cursor.execute(query)
    results = cursor.fetchall()
    cursor.close()
    conn.close()
    return render_template('indexG2.html', results=results, number = number)

@app.route('/graph3')
def graph3():
    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )
    cursor = conn.cursor()
    query = f"SELECT rolemenu.menuid, menu.menudescription FROM rolemenu JOIN menu ON rolemenu.menuid = menu.menuid WHERE menu.status = 'true' AND rolemenu.roleid = {number}"

    cursor.execute(query)
    results = cursor.fetchall()
    cursor.close()
    conn.close()
    return render_template('indexG3.html', results=results, number = number)

@app.route('/graph4')
def graph4():
    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )
    cursor = conn.cursor()
    query = f"SELECT rolemenu.menuid, menu.menudescription FROM rolemenu JOIN menu ON rolemenu.menuid = menu.menuid WHERE menu.status = 'true' AND rolemenu.roleid = {number}"

    cursor.execute(query)
    results = cursor.fetchall()
    cursor.close()
    conn.close()
    return render_template('indexG4.html', results=results, number = number)

@app.route('/graph5')
def graph5():
    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )
    cursor = conn.cursor()
    query = f"SELECT rolemenu.menuid, menu.menudescription FROM rolemenu JOIN menu ON rolemenu.menuid = menu.menuid WHERE menu.status = 'true' AND rolemenu.roleid = {number}"

    cursor.execute(query)
    results = cursor.fetchall()
    cursor.close()
    conn.close()
    return render_template('indexG5.html', results=results, number = number)

@app.route('/graph6')
def graph6():
    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )
    cursor = conn.cursor()
    query = f"SELECT rolemenu.menuid, menu.menudescription FROM rolemenu JOIN menu ON rolemenu.menuid = menu.menuid WHERE menu.status = 'true' AND rolemenu.roleid = {number}"

    cursor.execute(query)
    results = cursor.fetchall()
    cursor.close()
    conn.close()
    return render_template('indexG6.html', results=results, number = number)

@app.route('/validate', methods=['POST'])
def validate():
    username = request.form['username']

    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )

    cursor = conn.cursor()
    cursor.execute(f"SELECT count(name_) FROM userrole JOIN usermode ON userrole.userid = usermode.userid WHERE roleid = 1 and name_ = '{username}'")
    result = cursor.fetchone()[0]

    if result > 0:
        return "<script>window.location.href='/menuAdmin';</script>"
    else:
        return "<script>alert('Access denied!'); window.location.href='/';</script>"

    
@app.route('/validate2', methods=['POST'])
def validate2():
    username = request.form['username']

    conn = psycopg2.connect(
        host="localhost",
        dbname="Candidate_List",
        user="postgres",
        password="Adduvaith789"
    )

    cursor = conn.cursor()
    cursor.execute(f"SELECT count(name_) FROM userrole JOIN usermode ON userrole.userid = usermode.userid WHERE roleid = 2 and name_ = '{username}'")
    result = cursor.fetchone()[0]

    if result > 0:
        return """
        <script>
            window.location.href = '/menuUser';
        </script>
        """
    else:
        return """
        <script>
            alert('Access denied!');
            window.location.href = '/';
        </script>
        """    

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [15/Jun/2023 11:26:24] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:26:25] "GET /admin HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:26:28] "POST /validate HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:26:28] "GET /menuAdmin HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:26:29] "GET /graph1 HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:26:30] "GET /graph_data1?quarter= HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:26:33] "GET /graph_data1?quarter=q1 HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:26:34] "GET /graph_data1?quarter=q2 HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:26:35] "GET /graph_data1?quarter=q3 HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:26:36] "GET /graph_data1?quarter=q4 HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:26:37] "GET /graph2 HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:26:37] "GET /graph_data2?quarter= HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:26:39] "GET /graph_data2?quarter=q1 HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:26:40] "GET /graph_data2?quarter=q2 HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:26:41] "GET /graph_data2?quarter=q3 HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:26:41] "GET /graph_data2?quarter=q4 HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:26:47] "GET /menuAdmin HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:26:49] "GET /graph6 HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:26:50] "GET /graph_data6?quarter= HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:26:52] "GET /menuAdmin HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:26:54] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:26:55] "GET /admin HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:26:59] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:27:00] "GET /user HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:27:04] "POST /validate2 HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:27:04] "GET /menuUser HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Jun/2023 11:29:33] "GET / HTTP/1.1" 200 -
