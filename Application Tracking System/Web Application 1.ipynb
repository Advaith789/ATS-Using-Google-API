# %%
from flask import Flask

app = Flask(__name__)

@app.route('/')
def hello():
    return 'Hello, World!'

if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template_string
import psycopg2

app = Flask(__name__)

@app.route('/')
def home():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawChart);
        function drawChart() {
          var data = google.visualization.arrayToDataTable([
            ['Task', 'Hours per Day'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options = {
            title: 'Species',
            pieHole: 0.4,
          };

          var chart = new google.visualization.PieChart(document.getElementById('donutchart'));
          chart.draw(data, options);
        }
      </script>
    </head>
    <body>
      <div id="donutchart" style="width: 900px; height: 500px;"></div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3)

if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template
import matplotlib.pyplot as plt
import psycopg2
import io
import base64

app = Flask(__name__)

@app.route('/')
def plot_data():
    conn = psycopg2.connect(database="NewDB", user="postgres", password="Adduvaith789", host="127.0.0.1", port="5432")
    cur = conn.cursor()
    cur.execute("SELECT * from iris")
    rows = cur.fetchall()

    x = []
    y = []

    for row in rows:
        x.append(row[1])
        y.append(row[2])

    # Create the scatter plot
    plt.scatter(x, y)
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.title('Data Plot')

    # Save the plot to a buffer
    buffer = io.BytesIO()
    plt.savefig(buffer, format='png')
    buffer.seek(0)

    # Encode the buffer to base64
    plot_data = base64.b64encode(buffer.getvalue()).decode()

    conn.close()

    # Pass the plot data to the template
    return render_template('chart.html', plot_data=plot_data)

if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template_string
import psycopg2

app = Flask(__name__)

@app.route('/')
def home():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);
        
        function drawCharts() {
          var data1 = google.visualization.arrayToDataTable([
            ['Task', 'Hours per Day'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options1 = {
            title: 'Species 1',
            pieHole: 0.4,
          };

          var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);
          
          var data2 = google.visualization.arrayToDataTable([
            ['Category', 'Value'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options2 = {
            title: 'My Bar Chart'
          };

          var chart2 = new google.visualization.BarChart(document.getElementById('chart_div'));
          chart2.draw(data2, options2);
        }
      </script>
    </head>
    <body>
      <div id="donutchart1" style="width: 700px; height: 300px; display: inline-block;"></div>
      <div id="chart_div" style="width: 700px; height: 300px; display: inline-block;"></div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3)

if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template_string
import psycopg2

app = Flask(__name__)

@app.route('/')
def home():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <style>
        .charts-container {
          display: flex;
          justify-content: space-between;
          align-items: center;
          width: 900px;
          margin: 0 auto;
          padding-top: 50px;
        }

        .chart {
          width: 400px;
          height: 300px;
        }
      </style>
      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);
        
        function drawCharts() {
          var data1 = google.visualization.arrayToDataTable([
            ['Task', 'Hours per Day'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options1 = {
            title: 'Species 1',
            pieHole: 0.4,
          };

          var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);
          
          var data2 = google.visualization.arrayToDataTable([
            ['Category', 'Value'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options2 = {
            title: 'My Bar Chart'
          };

          var chart2 = new google.visualization.BarChart(document.getElementById('chart_div'));
          chart2.draw(data2, options2);
        }
      </script>
    </head>
    <body>
      <div class="charts-container">
        <div id="donutchart1" class="chart"></div>
        <div id="chart_div" class="chart"></div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3)

if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template_string
import psycopg2

app = Flask(__name__)

@app.route('/')
def home():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()
    
    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
        .charts-container {
          display: flex;
          justify-content: space-between;
          align-items: center;
          width: 900px;
          margin: 0 auto;
          padding-top: 50px;
        }

        .chart {
          width: 400px;
          height: 300px;
        }

        h1 {
          color: #333;
          font-size: 24px;
          text-align: center;
        }

        body {
          background-color: #f1f1f1;
        }
      </style>
      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);
        
        function drawCharts() {
          var data1 = google.visualization.arrayToDataTable([
            ['Task', 'Hours per Day'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options1 = {
            title: 'Species 1',
            pieHole: 0.4,
          };

          var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);
          
          var data2 = google.visualization.arrayToDataTable([
            ['Category', 'Value'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options2 = {
            title: 'My Bar Chart'
          };

          var chart2 = new google.visualization.BarChart(document.getElementById('chart_div'));
          chart2.draw(data2, options2);
        }

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });
        });
      </script>
    </head>
    <body>
      <h1 class="chart-title">Chart Dashboard</h1>
      <div class="charts-container">
        <div id="donutchart1" class="chart"></div>
        <div id="chart_div" class="chart"></div>
      </div>
      <div class="buttons-container">
        <button id="changeBgColorBtn">Change Background Color</button>
        <button id="changeTitleBtn">Change Chart Title</button>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3)

if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template_string
import psycopg2

app = Flask(__name__)

@app.route('/')
def home():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()
    
    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
        body {
          font-family: Arial, sans-serif;
          background-color: #f1f1f1;
          margin: 0;
          padding: 0;
        }

        .container {
          max-width: 900px;
          margin: 0 auto;
          padding: 20px;
        }

        .charts-container {
          display: flex;
          justify-content: space-between;
          align-items: center;
          margin-top: 50px;
        }

        .chart {
          width: 400px;
          height: 300px;
        }

        h1 {
          color: #333;
          font-size: 24px;
          text-align: center;
          margin-bottom: 30px;
        }

        .buttons-container {
          display: flex;
          justify-content: center;
          margin-top: 20px;
        }

        .button {
          background-color: #4CAF50;
          color: #fff;
          border: none;
          padding: 10px 20px;
          font-size: 16px;
          cursor: pointer;
          margin-right: 10px;
        }

        .button:hover {
          background-color: #45a049;
        }
      </style>
      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);
        
        function drawCharts() {
          var data1 = google.visualization.arrayToDataTable([
            ['Task', 'Hours per Day'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options1 = {
            title: 'Species 1',
            pieHole: 0.4,
          };

          var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);
          
          var data2 = google.visualization.arrayToDataTable([
            ['Category', 'Value'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options2 = {
            title: 'My Bar Chart'
          };

          var chart2 = new google.visualization.BarChart(document.getElementById('chart_div'));
          chart2.draw(data2, options2);
        }

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });
        });
      </script>
    </head>
    <body>
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="donutchart1" class="chart"></div>
          <div id="chart_div" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3)

if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template_string
import psycopg2

app = Flask(__name__)

@app.route('/')
def home():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]
    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='sentosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='sentosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()
    
    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
        body {
          font-family: Arial, sans-serif;
          background-color: #f1f1f1;
          margin: 0;
          padding: 0;
        }

        .container {
          max-width: 900px;
          margin: 0 auto;
          padding: 20px;
        }

        .charts-container {
          display: flex;
          justify-content: space-between;
          align-items: center;
          margin-top: 50px;
        }

        .chart {
          width: 400px;
          height: 300px;
        }

        h1 {
          color: #333;
          font-size: 24px;
          text-align: center;
          margin-bottom: 30px;
        }

        .buttons-container {
          display: flex;
          justify-content: center;
          margin-top: 20px;
        }

        .button {
          background-color: #4CAF50;
          color: #fff;
          border: none;
          padding: 10px 20px;
          font-size: 16px;
          cursor: pointer;
          margin-right: 10px;
        }

        .button:hover {
          background-color: #45a049;
        }
      </style>
      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);
        
        function drawCharts() {
          var data1 = google.visualization.arrayToDataTable([
            ['Task', 'Hours per Day'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options1 = {
            title: 'Species 1',
            pieHole: 0.4,
          };

          var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);
          
          var data2 = google.visualization.arrayToDataTable([
            ['Category', 'Value'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options2 = {
            title: 'My Bar Chart'
          };

          var chart2 = new google.visualization.BarChart(document.getElementById('chart_div'));
          chart2.draw(data2, options2);
          
          var data3 = google.visualization.arrayToDataTable([
            ['Species', 'Sepal Length', 'Sepal Width'],
            ['setosa', {{avgl1}}, {{avgw1}}],
            ['versicolor', {{avgl2}}, {{avgw2}}],
            ['virginica', {{avgl3}}, {{avgw3}}]
          ]);

          var options3 = {
            title: 'Species vs its Sepal Attributes',
            curveType: 'function',
            legend: { position: 'bottom' }
          };

          var chart3 = new google.visualization.LineChart(document.getElementById('curve_chart'));
          chart3.draw(data3, options3);
        }
        
        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });
        });
      </script>
    </head>
    <body>
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="donutchart1" class="chart"></div>
          <div id="chart_div" class="chart"></div>
          <div id="curve_chart" class = "chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1 = avgl1, avgl2 = avgl2, avgl3 = avgl3, avgw1 = avgw1, avgw2 = avgw2, avg = avgl1)

if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template_string
import psycopg2

app = Flask(__name__)

@app.route('/')
def home():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()
    
    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
    body {
      font-family: Arial, sans-serif;
      background-color: #f1f1f1;
      margin: 0;
      padding: 0;
    }

    .container {
      max-width: 9000px;
      margin: 0 auto;
      padding: 20px;
    }

    .charts-container {
      display: flex;
      justify-content: space-between;
      align-items: center;
      margin-top: 50px;
    }

    .chart {
      width: 5000px;
      height: 600px;
    }

    h1 {
      color: #333;
      font-size: 24px;
      text-align: center;
      margin-bottom: 30px;
    }

    .buttons-container {
      display: flex;
      justify-content: center;
      margin-top: 20px;
    }

    .button {
      background-color: #4CAF50;
      color: #fff;
      border: none;
      padding: 10px 20px;
      font-size: 16px;
      cursor: pointer;
      margin-right: 10px;
    }

    .button:hover {
      background-color: #45a049;
    }
</style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);
        
        function drawCharts() {
          var data1 = google.visualization.arrayToDataTable([
            ['Task', 'Hours per Day'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options1 = {
            title: 'Species 1',
            pieHole: 0.4,
          };

          var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);
          
          var data2 = google.visualization.arrayToDataTable([
            ['Category', 'Value'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options2 = {
            title: 'My Bar Chart'
          };

          var chart2 = new google.visualization.BarChart(document.getElementById('chart_div'));
          chart2.draw(data2, options2);
          
          var data3 = google.visualization.arrayToDataTable([
            ['Species', 'Sepal Length', 'Sepal Width'],
            ['setosa', {{ avgl1 }}, {{ avgw1 }}],
            ['versicolor', {{ avgl2 }}, {{ avgw2 }}],
            ['virginica', {{ avgl3 }}, {{ avgw3 }}]
          ]);

          var options3 = {
            title: 'Species vs its Sepal Attributes',
            curveType: 'function',
            legend: { position: 'bottom' }
          };

          var chart3 = new google.visualization.LineChart(document.getElementById('curve_chart'));
          chart3.draw(data3, options3);
        }
        
        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });
        });
      </script>
    </head>
    <body>
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="donutchart1" class="chart"></div>
          <div id="chart_div" class="chart"></div>
          <div id="curve_chart" class = "chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3)

if __name__ == '__main__':
    app.run()

# %%
import psycopg2
from IPython.display import HTML

# Establish a connection to the PostgreSQL database
conn = psycopg2.connect(
    database="NewDB",
    user="postgres",
    password="Adduvaith789",
    host="localhost",
    port="5432"
)

# Create a cursor object to interact with the database
cursor = conn.cursor()

# Fetch data from the database
query = "SELECT species, petallength, sepallength FROM iris;"
cursor.execute(query)
data = cursor.fetchall()

# Prepare the data for the chart
chart_data = [['Species', 'Petal Length', 'Sepal Length']] + data

# Generate the HTML code for the chart
html_code = f'''
<html>
  <head>
    <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
    <script type="text/javascript">
      google.charts.load('current', {{'packages':['corechart']}});
      google.charts.setOnLoadCallback(drawChart);

      function drawChart() {{
        var data = google.visualization.arrayToDataTable({chart_data});

        var options = {{
          title: 'Iris Flower Measurements',
          hAxis: {{title: 'Species'}},
          vAxis: {{title: 'Length'}}
        }};

        var chart = new google.visualization.BarChart(document.getElementById('chart_div'));
        chart.draw(data, options);
      }}
    </script>
  </head>
  <body>
    <div id="chart_div" style="width: 100%; height: 500px;"></div>
  </body>
</html>
'''

# Display the chart
HTML(html_code)

# %%
import psycopg2
import json
from IPython.display import HTML

# Establish a connection to the PostgreSQL database
conn = psycopg2.connect(
    database="NewDB",
    user="postgres",
    password="Adduvaith789",
    host="localhost",
    port="5432"
)

# Create a cursor object to interact with the database
cursor = conn.cursor()

# Fetch the data from the PostgreSQL database
query = "SELECT sepallength, species FROM iris"
cursor.execute(query)
rows = cursor.fetchall()

# Prepare the data for the bar chart
data = [['Species', 'Sepal Length']]
for row in rows:
    data.append(list(row))

# Load Google Charts and define the chart function
HTML_TEMPLATE = '''
<!DOCTYPE html>
<html>
  <head>
    <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
    <script type="text/javascript">
      google.charts.load('current', {'packages':['corechart']});
      google.charts.setOnLoadCallback(drawChart);

      function drawChart() {
        var data = google.visualization.arrayToDataTable(%s);

        var options = {
          title: 'Sepal Length by Species',
          legend: { position: 'none' },
        };

        var chart = new google.visualization.BarChart(document.getElementById('chart_div'));
        chart.draw(data, options);
      }
    </script>
  </head>
  <body>
    <div id="chart_div" style="width: 600px; height: 400px;"></div>
  </body>
</html>
'''

# Render the HTML template with the data
html_content = HTML_TEMPLATE % json.dumps(data)

# Display the chart using IPython display
display(HTML(html_content))

# %%
from flask import Flask, render_template_string, redirect, url_for
import psycopg2

app = Flask(__name__)

@app.route('/')
def home():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
        body {
          font-family: Arial, sans-serif;
          background-color: #f1f1f1;
          margin: 0;
          padding: 0;
        }

        .container {
          max-width: 9000px;
          margin: 0 auto;
          padding: 20px;
        }

        .charts-container {
          display: flex;
          justify-content: space-between;
          align-items: center;
          margin-top: 50px;
        }

        .chart {
          width: 5000px;
          height: 600px;
        }

        h1 {
          color: #333;
          font-size: 24px;
          text-align: center;
          margin-bottom: 30px;
        }

        .buttons-container {
          display: flex;
          justify-content: center;
          margin-top: 20px;
        }

        .button {
          background-color: #4CAF50;
          color: #fff;
          border: none;
          padding: 10px 20px;
          font-size: 16px;
          cursor: pointer;
          margin-right: 10px;
        }

        .button:hover {
          background-color: #45a049;
        }
      </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data1 = google.visualization.arrayToDataTable([
            ['Species', 'Count'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options1 = {
            title: 'Species 1',
            pieHole: 0.4,
          };

          var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);

          var data2 = google.visualization.arrayToDataTable([
            ['Category', 'Value'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options2 = {
            title: 'My Bar Chart'
          };

          var chart2 = new google.visualization.BarChart(document.getElementById('chart_div'));
          chart2.draw(data2, options2);

          var data3 = google.visualization.arrayToDataTable([
            ['Species', 'Sepal Length', 'Sepal Width'],
            ['setosa', {{ avgl1 }}, {{ avgw1 }}],
            ['versicolor', {{ avgl2 }}, {{ avgw2 }}],
            ['virginica', {{ avgl3 }}, {{ avgw3 }}]
          ]);

          var options3 = {
            title: 'Species vs its Sepal Attributes',
            curveType: 'function',
            legend: { position: 'bottom' }
          };

          var chart3 = new google.visualization.LineChart(document.getElementById('curve_chart'));
          chart3.draw(data3, options3);
        }

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#nextPageBtn').click(function() {
            window.location.href = "{{ url_for('next_page') }}";
          });
        });
      </script>
    </head>
    <body>
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="donutchart1" class="chart"></div>
          <div id="chart_div" class="chart"></div>
          <div id="curve_chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="nextPageBtn" class="button">Next Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3)

@app.route('/next_page')
def next_page():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
        body {
          font-family: Arial, sans-serif;
          background-color: #f1f1f1;
          margin: 0;
          padding: 0;
        }

        .container {
          max-width: 9000px;
          margin: 0 auto;
          padding: 20px;
        }

        h1 {
          color: #333;
          font-size: 24px;
          text-align: center;
          margin-bottom: 30px;
        }

        .charts-container {
          display: flex;
          justify-content: space-between;
          align-items: center;
          margin-top: 50px;
        }

        .chart {
          width: 500px;
          height: 400px;
        }

        .buttons-container {
          display: flex;
          justify-content: center;
          margin-top: 20px;
        }

        .button {
          background-color: #4CAF50;
          color: #fff;
          border: none;
          padding: 10px 20px;
          font-size: 16px;
          cursor: pointer;
          margin-right: 10px;
        }

        .button:hover {
          background-color: #45a049;
        }
      </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data1 = google.visualization.arrayToDataTable([
            ['Task', 'Hours per Day'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options1 = {
            title: 'Species Distribution',
            pieHole: 0.4,
          };

          var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);

          var data2 = google.visualization.arrayToDataTable([
            ['Category', 'Value'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options2 = {
            title: 'Species Distribution',
          };

          var chart2 = new google.visualization.BarChart(document.getElementById('chart_div'));
          chart2.draw(data2, options2);

          var data3 = google.visualization.arrayToDataTable([
            ['Species', 'Sepal Length', 'Sepal Width'],
            ['setosa', {{ avgl1 }}, {{ avgw1 }}],
            ['versicolor', {{ avgl2 }}, {{ avgw2 }}],
            ['virginica', {{ avgl3 }}, {{ avgw3 }}]
          ]);

          var options3 = {
            title: 'Species vs Sepal Attributes',
            curveType: 'function',
            legend: { position: 'bottom' }
          };

          var chart3 = new google.visualization.LineChart(document.getElementById('curve_chart'));
          chart3.draw(data3, options3);
        }

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the previous page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
        });
      </script>
    </head>
    <body>
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="donutchart1" class="chart"></div>
          <div id="chart_div" class="chart"></div>
          <div id="curve_chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Previous Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3)

if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template_string, redirect, url_for
import psycopg2

app = Flask(__name__)

@app.route('/')
def home():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
        body {
          font-family: Arial, sans-serif;
          background-color: #f1f1f1;
          margin: 0;
          padding: 0;
        }

        .container {
          max-width: 9000px;
          margin: 0 auto;
          padding: 20px;
        }

        .charts-container {
          display: flex;
          justify-content: space-between;
          align-items: center;
          margin-top: 50px;
        }

        .chart {
          width: 5000px;
          height: 600px;
        }

        h1 {
          color: #333;
          font-size: 24px;
          text-align: center;
          margin-bottom: 30px;
        }

        .buttons-container {
          display: flex;
          justify-content: center;
          margin-top: 20px;
        }

        .button {
          background-color: #4CAF50;
          color: #fff;
          border: none;
          padding: 10px 20px;
          font-size: 16px;
          cursor: pointer;
          margin-right: 10px;
        }

        .button:hover {
          background-color: #45a049;
        }
      </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data1 = google.visualization.arrayToDataTable([
            ['Species', 'Count'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options1 = {
            title: 'Species 1',
            pieHole: 0.4,
          };

          var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);

          var data2 = google.visualization.arrayToDataTable([
            ['Category', 'Value'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options2 = {
            title: 'My Bar Chart'
          };

          var chart2 = new google.visualization.BarChart(document.getElementById('chart_div'));
          chart2.draw(data2, options2);

          var data3 = google.visualization.arrayToDataTable([
            ['Species', 'Sepal Length', 'Sepal Width'],
            ['setosa', {{ avgl1 }}, {{ avgw1 }}],
            ['versicolor', {{ avgl2 }}, {{ avgw2 }}],
            ['virginica', {{ avgl3 }}, {{ avgw3 }}]
          ]);

          var options3 = {
            title: 'Species vs its Sepal Attributes',
            curveType: 'function',
            legend: { position: 'bottom' }
          };

          var chart3 = new google.visualization.LineChart(document.getElementById('curve_chart'));
          chart3.draw(data3, options3);
        }

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#nextPageBtn').click(function() {
            window.location.href = "{{ url_for('next_page') }}";
          });
        });
      </script>
    </head>
    <body>
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="donutchart1" class="chart"></div>
          <div id="chart_div" class="chart"></div>
          <div id="curve_chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="nextPageBtn" class="button">Next Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3)

@app.route('/next_page')
def next_page():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]

    
    
    #bubble chart values
    
    #Max Values - Versi
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    maxVersiPetalL = ma[0]
    
    cursor.execute("SELECT MAX(sepallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    maxVersiSepallL = ma[0]
    
    cursor.execute("SELECT MAX(petalwidth) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    maxVersiPetalW = ma[0]
    
    cursor.execute("SELECT MAX(sepalwidth) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    maxVersiSepallW = ma[0]
    
    
    #Max Values - setosa
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    maxsetosaPetalL = ma[0]
    
    cursor.execute("SELECT MAX(sepallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    maxsetosaSepallL = ma[0]
    
    cursor.execute("SELECT MAX(petalwidth) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    maxsetosaPetalW = ma[0]
    
    cursor.execute("SELECT MAX(sepalwidth) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    maxsetosaSepallW = ma[0]
    
    
    #Max Values - setosa
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    maxvirginicaPetalL = ma[0]
    
    cursor.execute("SELECT MAX(sepallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    maxvirginicaSepallL = ma[0]
    
    cursor.execute("SELECT MAX(petalwidth) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    maxvirginicaPetalW = ma[0]
    
    cursor.execute("SELECT MAX(sepalwidth) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    maxvirginicaSepallW = ma[0]
    
    
    
    
    
    
    
    
    #Min Values - Versi
    cursor.execute("SELECT MIN(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    minVersiPetalL = ma[0]
    
    cursor.execute("SELECT MIN(sepallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    minVersiSepallL = ma[0]
    
    cursor.execute("SELECT MIN(petalwidth) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    minVersiPetalW = ma[0]
    
    cursor.execute("SELECT MIN(sepalwidth) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    minVersiSepallW = ma[0]
    
    
   
    
    #Min Values - setosa
    cursor.execute("SELECT MIN(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    minsetosaPetalL = ma[0]
    
    cursor.execute("SELECT MIN(sepallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    minsetosaSepallL = ma[0]
    
    cursor.execute("SELECT MIN(petalwidth) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    minsetosaPetalW = ma[0]
    
    cursor.execute("SELECT MIN(sepalwidth) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    minsetosaSepallW = ma[0]
    
    
    #Min Values - Virginica
    cursor.execute("SELECT MIN(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    minvirginicaPetalL = ma[0]
    
    cursor.execute("SELECT MIN(sepallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    minvirginicaSepallL = ma[0]
    
    cursor.execute("SELECT MIN(petalwidth) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    minvirginicaPetalW = ma[0]
    
    cursor.execute("SELECT MIN(sepalwidth) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    minvirginicaSepallW = ma[0]
    
    
    
    
    
    
    #Avg Values - setosa
    cursor.execute("SELECT AVG(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    avgsetosaPetalL = ma[0]
    
    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    avgsetosaSepallL = ma[0]
    
    cursor.execute("SELECT AVG(petalwidth) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    avgsetosaPetalW = ma[0]
    
    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    avgsetosaSepallW = ma[0]
    
    
    #Avg Values - setosa
    cursor.execute("SELECT AVG(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    avgvirginicaPetalL = ma[0]
    
    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    avgvirginicaSepallL = ma[0]
    
    cursor.execute("SELECT AVG(petalwidth) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    avgvirginicaPetalW = ma[0]
    
    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    avgvirginicaSepallW = ma[0]
    
    
    
    
    cursor.execute("SELECT AVG(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    avgVersiPetalL = ma[0]
    
    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    avgVersiSepallL = ma[0]
    
    cursor.execute("SELECT AVG(petalwidth) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    avgVersiPetalW = ma[0]
    
    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    avgVersiSepallW = ma[0]
    
    
    
    
    
    
    
    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
        body {
          font-family: Arial, sans-serif;
          background-color: #f1f1f1;
          margin: 0;
          padding: 0;
        }

        .container {
          max-width: 9000px;
          margin: 0 auto;
          padding: 20px;
        }

        h1 {
          color: #333;
          font-size: 24px;
          text-align: center;
          margin-bottom: 30px;
        }

        .charts-container {
          display: flex;
          justify-content: space-between;
          align-items: center;
          margin-top: 50px;
        }

        .chart {
          width: 500px;
          height: 400px;
        }

        .buttons-container {
          display: flex;
          justify-content: center;
          margin-top: 20px;
        }

        .button {
          background-color: #4CAF50;
          color: #fff;
          border: none;
          padding: 10px 20px;
          font-size: 16px;
          cursor: pointer;
          margin-right: 10px;
        }

        .button:hover {
          background-color: #45a049;
        }
      </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data4 = google.visualization.arrayToDataTable([
            ['Species', 'Petal Length'],
            ['setosa', {{m1}}],
            ['versicolor', {{m2}}],
            ['virginica', {{m3}}]
          ]);

          var options4 = {
            title: 'Species vs Petal Length',
            vAxis: { title: 'Petal Length' },
            legend: { position: 'none' }
          };

          var chart4 = new google.visualization.ColumnChart(document.getElementById('column_chart'));
          chart4.draw(data4, options4);
          
          
          
            var data5 = google.visualization.arrayToDataTable([
            ['Species', 'Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width'],
            ['Setosa Max', {{maxsetosaSepallL}}, {{maxsetosaSepallW}}, {{maxsetosaPetalL}}, {{maxsetosaPetalW}}],
            ['Setosa Min', {{minsetosaSepallL}}, {{minsetosaSepallW}}, {{minsetosaPetalL}}, {{minsetosaPetalW}}],
            ['Setosa Avg',{{avgsetosaSepallL}}, {{avgsetosaSepallW}}, {{avgsetosaPetalL}}, {{avgsetosaPetalW}}],
            ['Versicolor Max', {{maxVersiSepallL}}, {{maxVersiSepallW}}, {{maxVersiPetalL}}, {{maxVersiPetalW}}],
            ['Versicolor Min', {{minVersiSepallL}},{{minVersiSepallW}}, {{minVersiPetalL}}, {{minVersiPetalW}}],
            ['Versicolor Avg', {{avgVersiSepallL}}, {{avgVersiSepallW}}, {{avgVersiPetalL}}, {{avgVersiPetalW}}],
            ['Virginica Max', {{maxvirginicaSepallL}}, {{maxvirginicaSepallW}}, {{maxvirginicaPetalL}}, {{maxvirginicaPetalW}}],
            ['Virginica Min', {{minvirginicaSepallL}}, {{minvirginicaSepallW}}, {{minvirginicaPetalL}}, {{minvirginicaPetalW}}],
            ['Virginica Avg', {{avgvirginicaSepallL}}, {{avgvirginicaSepallW}}, {{avgvirginicaPetalL}}, {{avgvirginicaPetalW}}]
          ]);
          
          var options5 = {
            title: 'Iris Dataset: Sepal Length vs Sepal Width',
            hAxis: { title: 'Sepal Length' },
            vAxis: { title: 'Sepal Width' },
            bubble: { textStyle: { fontSize: 11 } }
          };

          var chart = new google.visualization.BubbleChart(document.getElementById('chart'));
          chart.draw(data5, options5);
        }

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the previous page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
        });
      </script>
    </head>
    <body>
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="column_chart" class="chart"></div>
          <div id="chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Previous Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, maxsetosaSepallL=maxsetosaSepallL, maxsetosaSepallW=maxsetosaSepallW, maxsetosaPetalL=maxsetosaPetalL, maxsetosaPetalW=maxsetosaPetalW, minsetosaSepallL=minsetosaSepallL, minsetosaSepallW=minsetosaSepallW, minsetosaPetalL=minsetosaPetalL, minsetosaPetalW=minsetosaPetalW, avgsetosaSepallL=avgsetosaSepallL, avgsetosaSepallW=avgsetosaSepallW, avgsetosaPetalL=avgsetosaPetalL, avgsetosaPetalW=avgsetosaPetalW, maxVersiSepallL=maxVersiSepallL, maxVersiSepallW=maxVersiSepallW, maxVersiPetalL=maxVersiPetalL, maxVersiPetalW=maxVersiPetalW, minVersiSepallL=minVersiSepallL, minVersiSepallW=minVersiSepallW, minVersiPetalL=minVersiPetalL, avgVersiSepallL=avgVersiSepallL, avgVersiSepallW=avgVersiSepallW, avgVersiPetalL=avgVersiPetalL, avgVersiPetalW=avgVersiPetalW, maxvirginicaSepallL=maxvirginicaSepallL, maxvirginicaSepallW=maxvirginicaSepallW, maxvirginicaPetalL=maxvirginicaPetalL, maxvirginicaPetalW=maxvirginicaPetalW, minvirginicaSepallL=minvirginicaSepallL, minvirginicaSepallW=minvirginicaSepallW, minvirginicaPetalL=minvirginicaPetalL, avgvirginicaSepallL=avgvirginicaSepallL, avgvirginicaSepallW=avgvirginicaSepallW, avgvirginicaPetalL=avgvirginicaPetalL, avgvirginicaPetalW=avgvirginicaPetalW,minvirginicaPetalW=minvirginicaPetalW)

if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template_string, redirect, url_for
import psycopg2

app = Flask(__name__)

@app.route('/')
def home():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
        body {
          font-family: Arial, sans-serif;
          background-color: #f1f1f1;
          margin: 0;
          padding: 0;
        }

        .container {
          max-width: 9000px;
          margin: 0 auto;
          padding: 20px;
        }

        .charts-container {
          display: flex;
          justify-content: space-between;
          align-items: center;
          margin-top: 50px;
        }

        .chart {
          width: 5000px;
          height: 600px;
        }

        h1 {
          color: #333;
          font-size: 24px;
          text-align: center;
          margin-bottom: 30px;
        }

        .buttons-container {
          display: flex;
          justify-content: center;
          margin-top: 20px;
        }

        .button {
          background-color: #4CAF50;
          color: #fff;
          border: none;
          padding: 10px 20px;
          font-size: 16px;
          cursor: pointer;
          margin-right: 10px;
        }

        .button:hover {
          background-color: #45a049;
        }
      </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data1 = google.visualization.arrayToDataTable([
            ['Species', 'Count'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options1 = {
            title: 'Species 1',
            pieHole: 0.4,
          };

          var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);

          var data2 = google.visualization.arrayToDataTable([
            ['Category', 'Value'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options2 = {
            title: 'My Bar Chart'
          };

          var chart2 = new google.visualization.BarChart(document.getElementById('chart_div'));
          chart2.draw(data2, options2);

          var data3 = google.visualization.arrayToDataTable([
            ['Species', 'Sepal Length', 'Sepal Width'],
            ['setosa', {{ avgl1 }}, {{ avgw1 }}],
            ['versicolor', {{ avgl2 }}, {{ avgw2 }}],
            ['virginica', {{ avgl3 }}, {{ avgw3 }}]
          ]);

          var options3 = {
            title: 'Species vs its Sepal Attributes',
            curveType: 'function',
            legend: { position: 'bottom' }
          };

          var chart3 = new google.visualization.LineChart(document.getElementById('curve_chart'));
          chart3.draw(data3, options3);
        }

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#nextPageBtn').click(function() {
            window.location.href = "{{ url_for('next_page') }}";
          });
        });
      </script>
    </head>
    <body>
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="donutchart1" class="chart"></div>
          <div id="chart_div" class="chart"></div>
          <div id="curve_chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="nextPageBtn" class="button">Next Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3)

@app.route('/next_page')
def next_page():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]

    
    
    #bubble chart values
    
    #Max Values - Versi
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    maxVersiPetalL = ma[0]
    
    cursor.execute("SELECT MAX(sepallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    maxVersiSepallL = ma[0]
    
    cursor.execute("SELECT MAX(petalwidth) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    maxVersiPetalW = ma[0]
    
    cursor.execute("SELECT MAX(sepalwidth) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    maxVersiSepallW = ma[0]
    
    
    #Max Values - setosa
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    maxsetosaPetalL = ma[0]
    
    cursor.execute("SELECT MAX(sepallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    maxsetosaSepallL = ma[0]
    
    cursor.execute("SELECT MAX(petalwidth) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    maxsetosaPetalW = ma[0]
    
    cursor.execute("SELECT MAX(sepalwidth) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    maxsetosaSepallW = ma[0]
    
    
    #Max Values - setosa
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    maxvirginicaPetalL = ma[0]
    
    cursor.execute("SELECT MAX(sepallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    maxvirginicaSepallL = ma[0]
    
    cursor.execute("SELECT MAX(petalwidth) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    maxvirginicaPetalW = ma[0]
    
    cursor.execute("SELECT MAX(sepalwidth) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    maxvirginicaSepallW = ma[0]
    
    
    
    
    
    
    
    
    #Min Values - Versi
    cursor.execute("SELECT MIN(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    minVersiPetalL = ma[0]
    
    cursor.execute("SELECT MIN(sepallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    minVersiSepallL = ma[0]
    
    cursor.execute("SELECT MIN(petalwidth) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    minVersiPetalW = ma[0]
    
    cursor.execute("SELECT MIN(sepalwidth) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    minVersiSepallW = ma[0]
    
    
   
    
    #Min Values - setosa
    cursor.execute("SELECT MIN(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    minsetosaPetalL = ma[0]
    
    cursor.execute("SELECT MIN(sepallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    minsetosaSepallL = ma[0]
    
    cursor.execute("SELECT MIN(petalwidth) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    minsetosaPetalW = ma[0]
    
    cursor.execute("SELECT MIN(sepalwidth) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    minsetosaSepallW = ma[0]
    
    
    #Min Values - Virginica
    cursor.execute("SELECT MIN(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    minvirginicaPetalL = ma[0]
    
    cursor.execute("SELECT MIN(sepallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    minvirginicaSepallL = ma[0]
    
    cursor.execute("SELECT MIN(petalwidth) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    minvirginicaPetalW = ma[0]
    
    cursor.execute("SELECT MIN(sepalwidth) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    minvirginicaSepallW = ma[0]
    
    
    
    
    
    
    #Avg Values - setosa
    cursor.execute("SELECT AVG(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    avgsetosaPetalL = ma[0]
    
    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    avgsetosaSepallL = ma[0]
    
    cursor.execute("SELECT AVG(petalwidth) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    avgsetosaPetalW = ma[0]
    
    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    avgsetosaSepallW = ma[0]
    
    
    #Avg Values - setosa
    cursor.execute("SELECT AVG(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    avgvirginicaPetalL = ma[0]
    
    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    avgvirginicaSepallL = ma[0]
    
    cursor.execute("SELECT AVG(petalwidth) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    avgvirginicaPetalW = ma[0]
    
    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    avgvirginicaSepallW = ma[0]
    
    
    
    
    cursor.execute("SELECT AVG(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    avgVersiPetalL = ma[0]
    
    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    avgVersiSepallL = ma[0]
    
    cursor.execute("SELECT AVG(petalwidth) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    avgVersiPetalW = ma[0]
    
    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    avgVersiSepallW = ma[0]
    
    
    
    
    
    
    
    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
        body {
          font-family: Arial, sans-serif;
          background-color: #f1f1f1;
          margin: 0;
          padding: 0;
        }

        .container {
          max-width: 9000px;
          margin: 0 auto;
          padding: 20px;
        }

        h1 {
          color: #333;
          font-size: 24px;
          text-align: center;
          margin-bottom: 30px;
        }

        .charts-container {
          display: flex;
          justify-content: space-between;
          align-items: center;
          margin-top: 50px;
        }

        .chart {
          width: 500px;
          height: 400px;
        }

        .buttons-container {
          display: flex;
          justify-content: center;
          margin-top: 20px;
        }

        .button {
          background-color: #4CAF50;
          color: #fff;
          border: none;
          padding: 10px 20px;
          font-size: 16px;
          cursor: pointer;
          margin-right: 10px;
        }

        .button:hover {
          background-color: #45a049;
        }
      </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data4 = google.visualization.arrayToDataTable([
            ['Species', 'Petal Length'],
            ['setosa', {{m1}}],
            ['versicolor', {{m2}}],
            ['virginica', {{m3}}]
          ]);

          var options4 = {
            title: 'Species vs Petal Length',
            vAxis: { title: 'Petal Length' },
            legend: { position: 'none' }
          };

          var chart4 = new google.visualization.ColumnChart(document.getElementById('column_chart'));
          chart4.draw(data4, options4);
        }

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the previous page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
        });
      </script>
    </head>
    <body>
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="column_chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Previous Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, maxsetosaSepallL=maxsetosaSepallL, maxsetosaSepallW=maxsetosaSepallW, maxsetosaPetalL=maxsetosaPetalL, maxsetosaPetalW=maxsetosaPetalW, minsetosaSepallL=minsetosaSepallL, minsetosaSepallW=minsetosaSepallW, minsetosaPetalL=minsetosaPetalL, minsetosaPetalW=minsetosaPetalW, avgsetosaSepallL=avgsetosaSepallL, avgsetosaSepallW=avgsetosaSepallW, avgsetosaPetalL=avgsetosaPetalL, avgsetosaPetalW=avgsetosaPetalW, maxVersiSepallL=maxVersiSepallL, maxVersiSepallW=maxVersiSepallW, maxVersiPetalL=maxVersiPetalL, maxVersiPetalW=maxVersiPetalW, minVersiSepallL=minVersiSepallL, minVersiSepallW=minVersiSepallW, minVersiPetalL=minVersiPetalL, avgVersiSepallL=avgVersiSepallL, avgVersiSepallW=avgVersiSepallW, avgVersiPetalL=avgVersiPetalL, avgVersiPetalW=avgVersiPetalW, maxvirginicaSepallL=maxvirginicaSepallL, maxvirginicaSepallW=maxvirginicaSepallW, maxvirginicaPetalL=maxvirginicaPetalL, maxvirginicaPetalW=maxvirginicaPetalW, minvirginicaSepallL=minvirginicaSepallL, minvirginicaSepallW=minvirginicaSepallW, minvirginicaPetalL=minvirginicaPetalL, avgvirginicaSepallL=avgvirginicaSepallL, avgvirginicaSepallW=avgvirginicaSepallW, avgvirginicaPetalL=avgvirginicaPetalL, avgvirginicaPetalW=avgvirginicaPetalW,minvirginicaPetalW=minvirginicaPetalW)

if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template_string, redirect, url_for
import psycopg2

app = Flask(__name__)

@app.route('/')
def home():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
        body {
          font-family: Arial, sans-serif;
          background-color: #f1f1f1;
          margin: 0;
          padding: 0;
        }

        .container {
          max-width: 9000px;
          margin: 0 auto;
          padding: 20px;
        }

        .charts-container {
          display: flex;
          justify-content: space-between;
          align-items: center;
          margin-top: 50px;
        }

        .chart {
          width: 5000px;
          height: 600px;
        }

        h1 {
          color: #333;
          font-size: 24px;
          text-align: center;
          margin-bottom: 30px;
        }

        .buttons-container {
          display: flex;
          justify-content: center;
          margin-top: 20px;
        }

        .button {
          background-color: #4CAF50;
          color: #fff;
          border: none;
          padding: 10px 20px;
          font-size: 16px;
          cursor: pointer;
          margin-right: 10px;
        }

        .button:hover {
          background-color: #45a049;
        }
      </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data1 = google.visualization.arrayToDataTable([
            ['Species', 'Count'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options1 = {
            title: 'Species 1',
            pieHole: 0.4,
          };

          var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);

          var data2 = google.visualization.arrayToDataTable([
            ['Category', 'Value'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options2 = {
            title: 'My Bar Chart'
          };

          var chart2 = new google.visualization.BarChart(document.getElementById('chart_div'));
          chart2.draw(data2, options2);

          var data3 = google.visualization.arrayToDataTable([
            ['Species', 'Sepal Length', 'Sepal Width'],
            ['setosa', {{ avgl1 }}, {{ avgw1 }}],
            ['versicolor', {{ avgl2 }}, {{ avgw2 }}],
            ['virginica', {{ avgl3 }}, {{ avgw3 }}]
          ]);

          var options3 = {
            title: 'Species vs its Sepal Attributes',
            curveType: 'function',
            legend: { position: 'bottom' }
          };

          var chart3 = new google.visualization.LineChart(document.getElementById('curve_chart'));
          chart3.draw(data3, options3);
        }

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#nextPageBtn').click(function() {
            window.location.href = "{{ url_for('next_page') }}";
          });
        });
      </script>
    </head>
    <body>
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="donutchart1" class="chart"></div>
          <div id="chart_div" class="chart"></div>
          <div id="curve_chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="nextPageBtn" class="button">Next Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3)

@app.route('/next_page')
def next_page():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
        body {
          font-family: Arial, sans-serif;
          background-color: #f1f1f1;
          margin: 0;
          padding: 0;
        }

        .container {
          max-width: 9000px;
          margin: 0 auto;
          padding: 20px;
        }

        h1 {
          color: #333;
          font-size: 24px;
          text-align: center;
          margin-bottom: 30px;
        }

        .charts-container {
          display: flex;
          justify-content: space-between;
          align-items: center;
          margin-top: 50px;
        }

        .chart {
          width: 500px;
          height: 400px;
        }

        .buttons-container {
          display: flex;
          justify-content: center;
          margin-top: 20px;
        }

        .button {
          background-color: #4CAF50;
          color: #fff;
          border: none;
          padding: 10px 20px;
          font-size: 16px;
          cursor: pointer;
          margin-right: 10px;
        }

        .button:hover {
          background-color: #45a049;
        }
      </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data4 = google.visualization.arrayToDataTable([
            ['Species', 'Petal Length'],
            ['setosa', {{m1}}],
            ['versicolor', {{m2}}],
            ['virginica', {{m3}}]
          ]);

          var options4 = {
            title: 'Species vs Petal Length',
            vAxis: { title: 'Petal Length' },
            legend: { position: 'none' }
          };

          var chart4 = new google.visualization.ColumnChart(document.getElementById('column_chart'));
          chart4.draw(data4, options4);

          var data = new google.visualization.DataTable();
          data.addColumn('number', 'X');
          data.addColumn('number', 'Y');

          // Populate the data rows from the fetched data
          var rows = [
    '''

    for row in rows:
        html_code += "        [{}],\n".format(','.join(str(value) for value in row))

    html_code += '''
    ];

          data.addRows(rows);

          var options = {
              title: 'Scatter Plot',
              hAxis: {title: 'Petal_Length'},
              vAxis: {title: 'Sepal_Length'},
              legend: 'none'
          };

          var chart = new google.visualization.ScatterChart(document.getElementById('chart_div'));
          chart.draw(data, options);
        }

        google.charts.setOnLoadCallback(drawChart);

    $(document).ready(function() {
      // Change the background color on button click
      $('#changeBgColorBtn').click(function() {
        $('body').css('background-color', '#c7d6eb');
      });

      // Change the chart title on button click
      $('#changeTitleBtn').click(function() {
        $('.chart-title').text('Updated Chart Title');
      });

      // Redirect to the previous page on button click
      $('#prevPageBtn').click(function() {
        window.location.href = "{{ url_for('home') }}";
      });
        });
      </script>
    </head>
    <body>
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="column_chart" class="chart"></div>
          <div id="chart_div" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Previous Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)

if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template_string, redirect, url_for
import psycopg2

app = Flask(__name__)

@app.route('/')
def home():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
        body {
          font-family: Arial, sans-serif;
          background-color: #f1f1f1;
          margin: 0;
          padding: 0;
        }

        .container {
          max-width: 9000px;
          margin: 0 auto;
          padding: 20px;
        }

        .charts-container {
          display: flex;
          justify-content: space-between;
          align-items: center;
          margin-top: 50px;
        }

        .chart {
          width: 5000px;
          height: 600px;
        }

        h1 {
          color: #333;
          font-size: 24px;
          text-align: center;
          margin-bottom: 30px;
        }

        .buttons-container {
          display: flex;
          justify-content: center;
          margin-top: 20px;
        }

        .button {
          background-color: #4CAF50;
          color: #fff;
          border: none;
          padding: 10px 20px;
          font-size: 16px;
          cursor: pointer;
          margin-right: 10px;
        }

        .button:hover {
          background-color: #45a049;
        }
      </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data1 = google.visualization.arrayToDataTable([
            ['Species', 'Count'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options1 = {
            title: 'Species 1',
            pieHole: 0.4,
          };

          var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);

          var data2 = google.visualization.arrayToDataTable([
            ['Category', 'Value'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options2 = {
            title: 'My Bar Chart'
          };

          var chart2 = new google.visualization.BarChart(document.getElementById('chart_div'));
          chart2.draw(data2, options2);

          var data3 = google.visualization.arrayToDataTable([
            ['Species', 'Sepal Length', 'Sepal Width'],
            ['setosa', {{ avgl1 }}, {{ avgw1 }}],
            ['versicolor', {{ avgl2 }}, {{ avgw2 }}],
            ['virginica', {{ avgl3 }}, {{ avgw3 }}]
          ]);

          var options3 = {
            title: 'Species vs its Sepal Attributes',
            curveType: 'function',
            legend: { position: 'bottom' }
          };

          var chart3 = new google.visualization.LineChart(document.getElementById('curve_chart'));
          chart3.draw(data3, options3);
        }

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#nextPageBtn').click(function() {
            window.location.href = "{{ url_for('next_page') }}";
          });
        });
      </script>
    </head>
    <body>
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="donutchart1" class="chart"></div>
          <div id="chart_div" class="chart"></div>
          <div id="curve_chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="nextPageBtn" class="button">Next Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3)

@app.route('/next_page')
def next_page():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
        body {
          font-family: Arial, sans-serif;
          background-color: #f1f1f1;
          margin: 0;
          padding: 0;
        }

        .container {
          max-width: 9000px;
          margin: 0 auto;
          padding: 20px;
        }

        h1 {
          color: #333;
          font-size: 24px;
          text-align: center;
          margin-bottom: 30px;
        }

        .charts-container {
          display: flex;
          justify-content: space-between;
          align-items: center;
          margin-top: 50px;
        }

        .chart {
          width: 500px;
          height: 400px;
        }

        .buttons-container {
          display: flex;
          justify-content: center;
          margin-top: 20px;
        }

        .button {
          background-color: #4CAF50;
          color: #fff;
          border: none;
          padding: 10px 20px;
          font-size: 16px;
          cursor: pointer;
          margin-right: 10px;
        }

        .button:hover {
          background-color: #45a049;
        }
      </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data4 = google.visualization.arrayToDataTable([
            ['Species', 'Petal Length'],
            ['setosa', {{m1}}],
            ['versicolor', {{m2}}],
            ['virginica', {{m3}}]
          ]);

          var options4 = {
            title: 'Species vs Petal Length',
            vAxis: { title: 'Petal Length' },
            legend: { position: 'none' }
          };

          var chart4 = new google.visualization.ColumnChart(document.getElementById('column_chart'));
          chart4.draw(data4, options4);

          var data = new google.visualization.DataTable();
          data.addColumn('number', 'X');
          data.addColumn('number', 'Y');

          // Populate the data rows from the fetched data
          var rows = [
    '''

    for row in rows:
        html_code += "        [{}],\n".format(','.join(str(value) for value in row))

    html_code += '''
    ];

          data.addRows(rows);

          var options = {
              title: 'Scatter Plot',
              hAxis: {title: 'Petal_Length'},
              vAxis: {title: 'Sepal_Length'},
              legend: 'none'
          };

          var chart = new google.visualization.ScatterChart(document.getElementById('chart_div1'));
          chart.draw(data, options);
        
        var data6 = google.visualization.arrayToDataTable([
        ['Species', 'Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width'],
        ['Setosa', 5.1, 3.5, 1.4, 0.2],
        ['Setosa', 4.9, 3.0, 1.4, 0.2],
        ['Setosa', 4.7, 3.2, 1.3, 0.2],
        ['Versicolor', 7.0, 3.2, 4.7, 1.4],
        ['Versicolor', 6.4, 3.2, 4.5, 1.5],
        ['Versicolor', 6.9, 3.1, 4.9, 1.5],
        ['Virginica', 6.3, 3.3, 6.0, 2.5],
        ['Virginica', 5.8, 2.7, 5.1, 1.9],
        ['Virginica', 7.1, 3.0, 5.9, 2.1]
      ]);

      var options6 = {
        title: 'Iris Dataset: Sepal Length vs Sepal Width',
        hAxis: { title: 'Sepal Length' },
        vAxis: { title: 'Sepal Width' },
        bubble: { textStyle: { fontSize: 11 } }
      };

      var chart = new google.visualization.BubbleChart(document.getElementById('chart'));
      chart.draw(data6, options6);
    }
        google.charts.setOnLoadCallback(drawChart);

    $(document).ready(function() {
      // Change the background color on button click
      $('#changeBgColorBtn').click(function() {
        $('body').css('background-color', '#c7d6eb');
      });

      // Change the chart title on button click
      $('#changeTitleBtn').click(function() {
        $('.chart-title').text('Updated Chart Title');
      });

      // Redirect to the previous page on button click
      $('#prevPageBtn').click(function() {
        window.location.href = "{{ url_for('home') }}";
      });
    });
    </script>
    </head>
    <body>
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="column_chart" class="chart"></div>
          <div id="chart" class="chart"></div>
          <div id="chart_div1" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Previous Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)

if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template_string, redirect, url_for
import psycopg2

app = Flask(__name__)

@app.route('/')
def home():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
    body {
      font-family: Arial, sans-serif;
      background-color: #f1f1f1;
      margin: 0;
      padding: 0;
    }

    .container {
      max-width: 100%;
      margin: 0 auto;
      padding: 20px;
    }

    h1 {
      color: #333;
      font-size: 24px;
      text-align: center;
      margin-bottom: 30px;
    }

    .charts-container {
      display: flex;
      flex-wrap: wrap;
      justify-content: center;
      align-items: flex-start;
      margin-top: 50px;
    }

    .chart {
      width: 100%;
      max-width: 500px;
      height: 400px;
      margin: 10px;
    }

    .buttons-container {
      display: flex;
      justify-content: center;
      margin-top: 20px;
      flex-wrap: wrap;
    }

    .button {
      background-color: #4CAF50;
      color: #fff;
      border: none;
      padding: 10px 20px;
      font-size: 16px;
      cursor: pointer;
      margin: 5px;
    }

    .button:hover {
      background-color: #45a049;
    }
  </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data1 = google.visualization.arrayToDataTable([
            ['Species', 'Count'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options1 = {
            title: 'Species 1',
            pieHole: 0.4,
          };

          var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);

          var data2 = google.visualization.arrayToDataTable([
            ['Category', 'Value'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options2 = {
            title: 'My Bar Chart'
          };

          var chart2 = new google.visualization.BarChart(document.getElementById('chart_div'));
          chart2.draw(data2, options2);

          var data3 = google.visualization.arrayToDataTable([
            ['Species', 'Sepal Length', 'Sepal Width'],
            ['setosa', {{ avgl1 }}, {{ avgw1 }}],
            ['versicolor', {{ avgl2 }}, {{ avgw2 }}],
            ['virginica', {{ avgl3 }}, {{ avgw3 }}]
          ]);

          var options3 = {
            title: 'Species vs its Sepal Attributes',
            curveType: 'function',
            legend: { position: 'bottom' }
          };

          var chart3 = new google.visualization.LineChart(document.getElementById('curve_chart'));
          chart3.draw(data3, options3);
        }

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#nextPageBtn').click(function() {
            window.location.href = "{{ url_for('next_page') }}";
          });
        });
      </script>
    </head>
    <body>
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="donutchart1" class="chart"></div>
          <div id="chart_div" class="chart"></div>
          <div id="curve_chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="nextPageBtn" class="button">Next Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3)

@app.route('/next_page')
def next_page():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
        <style>
    body {
      font-family: Arial, sans-serif;
      background-color: #f1f1f1;
      margin: 0;
      padding: 0;
    }

    .container {
      max-width: 100%;
      margin: 0 auto;
      padding: 20px;
    }

    h1 {
      color: #333;
      font-size: 24px;
      text-align: center;
      margin-bottom: 30px;
    }

    .charts-container {
      display: flex;
      flex-wrap: wrap;
      justify-content: center;
      align-items: flex-start;
      margin-top: 50px;
    }

    .chart {
      width: 100%;
      max-width: 500px;
      height: 400px;
      margin: 10px;
    }

    .buttons-container {
      display: flex;
      justify-content: center;
      margin-top: 20px;
      flex-wrap: wrap;
    }

    .button {
      background-color: #4CAF50;
      color: #fff;
      border: none;
      padding: 10px 20px;
      font-size: 16px;
      cursor: pointer;
      margin: 5px;
    }

    .button:hover {
      background-color: #45a049;
    }
  </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data4 = google.visualization.arrayToDataTable([
            ['Species', 'Petal Length'],
            ['setosa', {{m1}}],
            ['versicolor', {{m2}}],
            ['virginica', {{m3}}]
          ]);

          var options4 = {
            title: 'Species vs Petal Length',
            vAxis: { title: 'Petal Length' },
            legend: { position: 'none' }
          };

          var chart4 = new google.visualization.ColumnChart(document.getElementById('column_chart'));
          chart4.draw(data4, options4);

          var data = new google.visualization.DataTable();
          data.addColumn('number', 'X');
          data.addColumn('number', 'Y');

          // Populate the data rows from the fetched data
          var rows = [
    '''

    for row in rows:
        html_code += "        [{}],\n".format(','.join(str(value) for value in row))

    html_code += '''
    ];

          data.addRows(rows);

          var options = {
              title: 'Scatter Plot',
              hAxis: {title: 'Petal_Length'},
              vAxis: {title: 'Sepal_Length'},
              legend: 'none'
          };

          var chart = new google.visualization.ScatterChart(document.getElementById('chart_div1'));
          chart.draw(data, options);
        
        var data6 = google.visualization.arrayToDataTable([
        ['Species', 'Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width'],
        ['Setosa', 5.1, 3.5, 1.4, 0.2],
        ['Setosa', 4.9, 3.0, 1.4, 0.2],
        ['Setosa', 4.7, 3.2, 1.3, 0.2],
        ['Versicolor', 7.0, 3.2, 4.7, 1.4],
        ['Versicolor', 6.4, 3.2, 4.5, 1.5],
        ['Versicolor', 6.9, 3.1, 4.9, 1.5],
        ['Virginica', 6.3, 3.3, 6.0, 2.5],
        ['Virginica', 5.8, 2.7, 5.1, 1.9],
        ['Virginica', 7.1, 3.0, 5.9, 2.1]
      ]);

      var options6 = {
        title: 'Iris Dataset: Sepal Length vs Sepal Width',
        hAxis: { title: 'Sepal Length' },
        vAxis: { title: 'Sepal Width' },
        bubble: { textStyle: { fontSize: 11 } }
      };

      var chart = new google.visualization.BubbleChart(document.getElementById('chart'));
      chart.draw(data6, options6);
    }
        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the previous page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
        });
      </script>
    </head>
    <body>
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="column_chart" class="chart"></div>
          <div id="chart" class="chart"></div>
          <div id="chart_div1" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Previous Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)

if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template_string, redirect, url_for
import psycopg2

app = Flask(__name__)

@app.route('/')
def home():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
    body {
      font-family: Arial, sans-serif;
      background-color: #f1f1f1;
      margin: 0;
      padding: 0;
    }
    
    
    
    
    
    
    ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
        }

        ul.graph-menu li {
            float: left;
        }

        ul.graph-menu li a {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            text-decoration: none;
            transition: background-color 0.3s;
        }

        ul.graph-menu li a:hover {
            background-color: #f1f1f1;
        }

        ul.graph-menu li a.active {
            background-color: #4CAF50;
            color: white;
        }
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    .container {
      max-width: 100%;
      margin: 0 auto;
      padding: 20px;
    }

    h1 {
      color: #333;
      font-size: 24px;
      text-align: center;
      margin-bottom: 30px;
    }

    .charts-container {
      display: flex;
      flex-wrap: wrap;
      justify-content: center;
      align-items: flex-start;
      margin-top: 50px;
    }

    .chart {
      width: 100%;
      max-width: 500px;
      height: 400px;
      margin: 10px;
    }

    .buttons-container {
      display: flex;
      justify-content: center;
      margin-top: 20px;
      flex-wrap: wrap;
    }

    .button {
      background-color: #4CAF50;
      color: #fff;
      border: none;
      padding: 10px 20px;
      font-size: 16px;
      cursor: pointer;
      margin: 5px;
    }

    .button:hover {
      background-color: #45a049;
    }
  </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data1 = google.visualization.arrayToDataTable([
            ['Species', 'Count'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options1 = {
            title: 'Species 1',
            pieHole: 0.4,
          };

          var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);

          var data2 = google.visualization.arrayToDataTable([
            ['Category', 'Value'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options2 = {
            title: 'My Bar Chart'
          };

          var chart2 = new google.visualization.BarChart(document.getElementById('chart_div'));
          chart2.draw(data2, options2);

          var data3 = google.visualization.arrayToDataTable([
            ['Species', 'Sepal Length', 'Sepal Width'],
            ['setosa', {{ avgl1 }}, {{ avgw1 }}],
            ['versicolor', {{ avgl2 }}, {{ avgw2 }}],
            ['virginica', {{ avgl3 }}, {{ avgw3 }}]
          ]);

          var options3 = {
            title: 'Species vs its Sepal Attributes',
            curveType: 'function',
            legend: { position: 'bottom' }
          };

          var chart3 = new google.visualization.LineChart(document.getElementById('curve_chart'));
          chart3.draw(data3, options3);
        }
        
        
        
        
        
        
        function showGraph(graphId) {
            // Hide all graphs
            var graphs = document.querySelectorAll("#content > div");
            for (var i = 0; i < graphs.length; i++) {
                graphs[i].style.display = "none";
            }

            // Show the selected graph
            var selectedGraph = document.getElementById(graphId);
            selectedGraph.style.display = "block";
        }

        // Function to select the graph and update the active class
        function selectGraph(graphId) {
            // Remove active class from all menu items
            var menuItems = document.querySelectorAll(".graph-menu li a");
            for (var i = 0; i < menuItems.length; i++) {
                menuItems[i].classList.remove("active");
            }

            // Add active class to the selected menu item
            var selectedMenuItem = document.querySelector('a[href="#' + graphId + '"]');
            selectedMenuItem.classList.add("active");

            // Show the selected graph
            showGraph(graphId);
        }


        
        
        
        
        
        
        
        
        
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#nextPageBtn').click(function() {
            window.location.href = "{{ url_for('next_page') }}";
          });
          
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
        <li><a class="active" href="#graph1" onclick="selectGraph('graph1')">Graph 1</a></li>
        <li><a href="#graph2" onclick="selectGraph('graph2')">Graph 2</a></li>
        <li><a href="#graph3" onclick="selectGraph('graph3')">Graph 3</a></li>
        <li><a href="#graph4" onclick="selectGraph('graph4')">Graph 4</a></li>
        <li><a href="#graph5" onclick="selectGraph('graph5')">Graph 5</a></li>
        <li><a href="#graph6" onclick="selectGraph('graph6')">Graph 6</a></li>
    </ul>

    <!-- Content area for displaying the graphs -->
    <div id="content">
        <div id="graph1" style="display: none;"> var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);</div>
        <div id="graph2" style="display: none;">Graph 2 Content</div>
        <div id="graph3" style="display: none;">Graph 3 Content</div>
        <div id="graph4" style="display: none;">Graph 4 Content</div>
        <div id="graph5" style="display: none;">Graph 5 Content</div>
        <div id="graph6" style="display: none;">Graph 6 Content</div>
    </div>
    
    
    
    
    
    
    
    
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="donutchart1" class="chart"></div>
          <div id="chart_div" class="chart"></div>
          <div id="curve_chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="nextPageBtn" class="button">Next Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3)

@app.route('/next_page')
def next_page():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
        <style>
    body {
      font-family: Arial, sans-serif;
      background-color: #f1f1f1;
      margin: 0;
      padding: 0;
    }







ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
        }

        ul.graph-menu li {
            float: left;
        }

        ul.graph-menu li a {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            text-decoration: none;
            transition: background-color 0.3s;
        }

        ul.graph-menu li a:hover {
            background-color: #f1f1f1;
        }

        ul.graph-menu li a.active {
            background-color: #4CAF50;
            color: white;
        }























    .container {
      max-width: 100%;
      margin: 0 auto;
      padding: 20px;
    }

    h1 {
      color: #333;
      font-size: 24px;
      text-align: center;
      margin-bottom: 30px;
    }

    .charts-container {
      display: flex;
      flex-wrap: wrap;
      justify-content: center;
      align-items: flex-start;
      margin-top: 50px;
    }

    .chart {
      width: 100%;
      max-width: 500px;
      height: 400px;
      margin: 10px;
    }

    .buttons-container {
      display: flex;
      justify-content: center;
      margin-top: 20px;
      flex-wrap: wrap;
    }

    .button {
      background-color: #4CAF50;
      color: #fff;
      border: none;
      padding: 10px 20px;
      font-size: 16px;
      cursor: pointer;
      margin: 5px;
    }

    .button:hover {
      background-color: #45a049;
    }
  </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data4 = google.visualization.arrayToDataTable([
            ['Species', 'Petal Length'],
            ['setosa', {{m1}}],
            ['versicolor', {{m2}}],
            ['virginica', {{m3}}]
          ]);

          var options4 = {
            title: 'Species vs Petal Length',
            vAxis: { title: 'Petal Length' },
            legend: { position: 'none' }
          };

          var chart4 = new google.visualization.ColumnChart(document.getElementById('column_chart'));
          chart4.draw(data4, options4);

          var data = new google.visualization.DataTable();
          data.addColumn('number', 'X');
          data.addColumn('number', 'Y');

          // Populate the data rows from the fetched data
          var rows = [
    '''

    for row in rows:
        html_code += "        [{}],\n".format(','.join(str(value) for value in row))

    html_code += '''
    ];

          data.addRows(rows);

          var options = {
              title: 'Scatter Plot',
              hAxis: {title: 'Petal_Length'},
              vAxis: {title: 'Sepal_Length'},
              legend: 'none'
          };

          var chart = new google.visualization.ScatterChart(document.getElementById('chart_div1'));
          chart.draw(data, options);
        
        var data6 = google.visualization.arrayToDataTable([
        ['Species', 'Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width'],
        ['Setosa', 5.1, 3.5, 1.4, 0.2],
        ['Setosa', 4.9, 3.0, 1.4, 0.2],
        ['Setosa', 4.7, 3.2, 1.3, 0.2],
        ['Versicolor', 7.0, 3.2, 4.7, 1.4],
        ['Versicolor', 6.4, 3.2, 4.5, 1.5],
        ['Versicolor', 6.9, 3.1, 4.9, 1.5],
        ['Virginica', 6.3, 3.3, 6.0, 2.5],
        ['Virginica', 5.8, 2.7, 5.1, 1.9],
        ['Virginica', 7.1, 3.0, 5.9, 2.1]
      ]);

      var options6 = {
        title: 'Iris Dataset: Sepal Length vs Sepal Width',
        hAxis: { title: 'Sepal Length' },
        vAxis: { title: 'Sepal Width' },
        bubble: { textStyle: { fontSize: 11 } }
      };

      var chart = new google.visualization.BubbleChart(document.getElementById('chart'));
      chart.draw(data6, options6);
    }
    
    
    
    
    
    
    function showGraph(graphId) {
            // Hide all graphs
            var graphs = document.querySelectorAll("#content > div");
            for (var i = 0; i < graphs.length; i++) {
                graphs[i].style.display = "none";
            }

            // Show the selected graph
            var selectedGraph = document.getElementById(graphId);
            selectedGraph.style.display = "block";
        }

        // Function to select the graph and update the active class
        function selectGraph(graphId) {
            // Remove active class from all menu items
            var menuItems = document.querySelectorAll(".graph-menu li a");
            for (var i = 0; i < menuItems.length; i++) {
                menuItems[i].classList.remove("active");
            }

            // Add active class to the selected menu item
            var selectedMenuItem = document.querySelector('a[href="#' + graphId + '"]');
            selectedMenuItem.classList.add("active");

            // Show the selected graph
            showGraph(graphId);
        }

    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the previous page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    <ul class="graph-menu">
        <li><a class="active" href="#graph1" onclick="selectGraph('graph1')">Graph 1</a></li>
        <li><a href="#graph2" onclick="selectGraph('graph2')">Graph 2</a></li>
        <li><a href="#graph3" onclick="selectGraph('graph3')">Graph 3</a></li>
        <li><a href="#graph4" onclick="selectGraph('graph4')">Graph 4</a></li>
        <li><a href="#graph5" onclick="selectGraph('graph5')">Graph 5</a></li>
        <li><a href="#graph6" onclick="selectGraph('graph6')">Graph 6</a></li>
    </ul>

    <!-- Content area for displaying the graphs -->
    <div id="content">
        <div id="graph1" style="display: none;">Graph 1 Content</div>
        <div id="graph2" style="display: none;">Graph 2 Content</div>
        <div id="graph3" style="display: none;">Graph 3 Content</div>
        <div id="graph4" style="display: none;">Graph 4 Content</div>
        <div id="graph5" style="display: none;">Graph 5 Content</div>
        <div id="graph6" style="display: none;">Graph 6 Content</div>
    </div>
    
    
    
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="column_chart" class="chart"></div>
          <div id="chart" class="chart"></div>
          <div id="chart_div1" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Previous Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)




if __name__ == '__main__':
    app.run()

# %% [markdown]
# <h1>Try to fix the Menu drop thing</h1>

# %%
from flask import Flask, render_template_string, redirect, url_for
import psycopg2

app = Flask(__name__)

@app.route('/')
def home():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
    body {
      font-family: Arial, sans-serif;
      background-color: #f1f1f1;
      margin: 0;
      padding: 0;
    }
    
    
    
    
    
    
    ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
        }

        ul.graph-menu li {
            float: left;
        }

        ul.graph-menu li a {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            text-decoration: none;
            transition: background-color 0.3s;
        }

        ul.graph-menu li a:hover {
            background-color: #f1f1f1;
        }

        ul.graph-menu li a.active {
            background-color: #4CAF50;
            color: white;
        }
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    .container {
      max-width: 100%;
      margin: 0 auto;
      padding: 20px;
    }

    h1 {
      color: #333;
      font-size: 24px;
      text-align: center;
      margin-bottom: 30px;
    }

    .charts-container {
      display: flex;
      flex-wrap: wrap;
      justify-content: center;
      align-items: flex-start;
      margin-top: 50px;
    }

    .chart {
      width: 100%;
      max-width: 500px;
      height: 400px;
      margin: 10px;
    }

    .buttons-container {
      display: flex;
      justify-content: center;
      margin-top: 20px;
      flex-wrap: wrap;
    }

    .button {
      background-color: #4CAF50;
      color: #fff;
      border: none;
      padding: 10px 20px;
      font-size: 16px;
      cursor: pointer;
      margin: 5px;
    }

    .button:hover {
      background-color: #45a049;
    }
  </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data1 = google.visualization.arrayToDataTable([
            ['Species', 'Count'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options1 = {
            title: 'Species 1',
            pieHole: 0.4,
          };

          var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);

          var data2 = google.visualization.arrayToDataTable([
            ['Category', 'Value'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options2 = {
            title: 'My Bar Chart'
          };

          var chart2 = new google.visualization.BarChart(document.getElementById('chart_div'));
          chart2.draw(data2, options2);

          var data3 = google.visualization.arrayToDataTable([
            ['Species', 'Sepal Length', 'Sepal Width'],
            ['setosa', {{ avgl1 }}, {{ avgw1 }}],
            ['versicolor', {{ avgl2 }}, {{ avgw2 }}],
            ['virginica', {{ avgl3 }}, {{ avgw3 }}]
          ]);

          var options3 = {
            title: 'Species vs its Sepal Attributes',
            curveType: 'function',
            legend: { position: 'bottom' }
          };

          var chart3 = new google.visualization.LineChart(document.getElementById('curve_chart'));
          chart3.draw(data3, options3);
        }
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#nextPageBtn').click(function() {
            window.location.href = "{{ url_for('next_page') }}";
          });

          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="donutchart1" class="chart"></div>
          <div id="chart_div" class="chart"></div>
          <div id="curve_chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="nextPageBtn" class="button">Next Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3)

@app.route('/next_page')
def next_page():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
        <style>
    body {
      font-family: Arial, sans-serif;
      background-color: #f1f1f1;
      margin: 0;
      padding: 0;
    }







ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
        }

        ul.graph-menu li {
            float: left;
        }

        ul.graph-menu li a {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            text-decoration: none;
            transition: background-color 0.3s;
        }

        ul.graph-menu li a:hover {
            background-color: #f1f1f1;
        }

        ul.graph-menu li a.active {
            background-color: #4CAF50;
            color: white;
        }























    .container {
      max-width: 100%;
      margin: 0 auto;
      padding: 20px;
    }

    h1 {
      color: #333;
      font-size: 24px;
      text-align: center;
      margin-bottom: 30px;
    }

    .charts-container {
      display: flex;
      flex-wrap: wrap;
      justify-content: center;
      align-items: flex-start;
      margin-top: 50px;
    }

    .chart {
      width: 100%;
      max-width: 500px;
      height: 400px;
      margin: 10px;
    }

    .buttons-container {
      display: flex;
      justify-content: center;
      margin-top: 20px;
      flex-wrap: wrap;
    }

    .button {
      background-color: #4CAF50;
      color: #fff;
      border: none;
      padding: 10px 20px;
      font-size: 16px;
      cursor: pointer;
      margin: 5px;
    }

    .button:hover {
      background-color: #45a049;
    }
  </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data4 = google.visualization.arrayToDataTable([
            ['Species', 'Petal Length'],
            ['setosa', {{m1}}],
            ['versicolor', {{m2}}],
            ['virginica', {{m3}}]
          ]);

          var options4 = {
            title: 'Species vs Petal Length',
            vAxis: { title: 'Petal Length' },
            legend: { position: 'none' }
          };

          var chart4 = new google.visualization.ColumnChart(document.getElementById('column_chart'));
          chart4.draw(data4, options4);

          var data = new google.visualization.DataTable();
          data.addColumn('number', 'X');
          data.addColumn('number', 'Y');

          // Populate the data rows from the fetched data
          var rows = [
    '''

    for row in rows:
        html_code += "        [{}],\n".format(','.join(str(value) for value in row))

    html_code += '''
    ];

          data.addRows(rows);

          var options = {
              title: 'Scatter Plot',
              hAxis: {title: 'Petal_Length'},
              vAxis: {title: 'Sepal_Length'},
              legend: 'none'
          };

          var chart = new google.visualization.ScatterChart(document.getElementById('chart_div1'));
          chart.draw(data, options);
        
        var data6 = google.visualization.arrayToDataTable([
        ['Species', 'Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width'],
        ['Setosa', 5.1, 3.5, 1.4, 0.2],
        ['Setosa', 4.9, 3.0, 1.4, 0.2],
        ['Setosa', 4.7, 3.2, 1.3, 0.2],
        ['Versicolor', 7.0, 3.2, 4.7, 1.4],
        ['Versicolor', 6.4, 3.2, 4.5, 1.5],
        ['Versicolor', 6.9, 3.1, 4.9, 1.5],
        ['Virginica', 6.3, 3.3, 6.0, 2.5],
        ['Virginica', 5.8, 2.7, 5.1, 1.9],
        ['Virginica', 7.1, 3.0, 5.9, 2.1]
      ]);

      var options6 = {
        title: 'Iris Dataset: Sepal Length vs Sepal Width',
        hAxis: { title: 'Sepal Length' },
        vAxis: { title: 'Sepal Width' },
        bubble: { textStyle: { fontSize: 11 } }
      };

      var chart = new google.visualization.BubbleChart(document.getElementById('chart'));
      chart.draw(data6, options6);
    }

    
        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the previous page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
  
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="column_chart" class="chart"></div>
          <div id="chart" class="chart"></div>
          <div id="chart_div1" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Previous Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)

























@app.route('/graph1')
def graph1():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
        <style>
    body {
      font-family: Arial, sans-serif;
      background-color: #f1f1f1;
      margin: 0;
      padding: 0;
    }







ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
        }

        ul.graph-menu li {
            float: left;
        }

        ul.graph-menu li a {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            text-decoration: none;
            transition: background-color 0.3s;
        }

        ul.graph-menu li a:hover {
            background-color: #f1f1f1;
        }

        ul.graph-menu li a.active {
            background-color: #4CAF50;
            color: white;
        }























    .container {
      max-width: 100%;
      margin: 0 auto;
      padding: 20px;
    }

    h1 {
      color: #333;
      font-size: 24px;
      text-align: center;
      margin-bottom: 30px;
    }

    .charts-container {
      display: flex;
      flex-wrap: wrap;
      justify-content: center;
      align-items: flex-start;
      margin-top: 50px;
    }

    .chart {
      width: 100%;
      max-width: 500px;
      height: 400px;
      margin: 10px;
    }

    .buttons-container {
      display: flex;
      justify-content: center;
      margin-top: 20px;
      flex-wrap: wrap;
    }

    .button {
      background-color: #4CAF50;
      color: #fff;
      border: none;
      padding: 10px 20px;
      font-size: 16px;
      cursor: pointer;
      margin: 5px;
    }

    .button:hover {
      background-color: #45a049;
    }
  </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data1 = google.visualization.arrayToDataTable([
            ['Species', 'Count'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options1 = {
            title: 'Species 1',
            pieHole: 0.4,
          };

          var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);
    }
    
    
    
    

 
    
    
    
    
    
        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the previous page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="donutchart1" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Previous Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)




@app.route('/graph2')
def graph2():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
    body {
      font-family: Arial, sans-serif;
      background-color: #f1f1f1;
      margin: 0;
      padding: 0;
    }
    
    
    
    
    
    
    ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
        }

        ul.graph-menu li {
            float: left;
        }

        ul.graph-menu li a {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            text-decoration: none;
            transition: background-color 0.3s;
        }

        ul.graph-menu li a:hover {
            background-color: #f1f1f1;
        }

        ul.graph-menu li a.active {
            background-color: #4CAF50;
            color: white;
        }
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    .container {
      max-width: 100%;
      margin: 0 auto;
      padding: 20px;
    }

    h1 {
      color: #333;
      font-size: 24px;
      text-align: center;
      margin-bottom: 30px;
    }

    .charts-container {
      display: flex;
      flex-wrap: wrap;
      justify-content: center;
      align-items: flex-start;
      margin-top: 50px;
    }

    .chart {
      width: 100%;
      max-width: 500px;
      height: 400px;
      margin: 10px;
    }

    .buttons-container {
      display: flex;
      justify-content: center;
      margin-top: 20px;
      flex-wrap: wrap;
    }

    .button {
      background-color: #4CAF50;
      color: #fff;
      border: none;
      padding: 10px 20px;
      font-size: 16px;
      cursor: pointer;
      margin: 5px;
    }

    .button:hover {
      background-color: #45a049;
    }
  </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {

          var data2 = google.visualization.arrayToDataTable([
            ['Category', 'Value'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options2 = {
            title: 'My Bar Chart'
          };

          var chart2 = new google.visualization.BarChart(document.getElementById('chart_div'));
          chart2.draw(data2, options2);
        }
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#nextPageBtn').click(function() {
            window.location.href = "{{ url_for('next_page') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="chart_div" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="nextPageBtn" class="button">Next Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3)





@app.route('/graph3')
def graph3():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
    body {
      font-family: Arial, sans-serif;
      background-color: #f1f1f1;
      margin: 0;
      padding: 0;
    }
    
    
    
    
    
    
    ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
        }

        ul.graph-menu li {
            float: left;
        }

        ul.graph-menu li a {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            text-decoration: none;
            transition: background-color 0.3s;
        }

        ul.graph-menu li a:hover {
            background-color: #f1f1f1;
        }

        ul.graph-menu li a.active {
            background-color: #4CAF50;
            color: white;
        }
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    .container {
      max-width: 100%;
      margin: 0 auto;
      padding: 20px;
    }

    h1 {
      color: #333;
      font-size: 24px;
      text-align: center;
      margin-bottom: 30px;
    }

    .charts-container {
      display: flex;
      flex-wrap: wrap;
      justify-content: center;
      align-items: flex-start;
      margin-top: 50px;
    }

    .chart {
      width: 100%;
      max-width: 500px;
      height: 400px;
      margin: 10px;
    }

    .buttons-container {
      display: flex;
      justify-content: center;
      margin-top: 20px;
      flex-wrap: wrap;
    }

    .button {
      background-color: #4CAF50;
      color: #fff;
      border: none;
      padding: 10px 20px;
      font-size: 16px;
      cursor: pointer;
      margin: 5px;
    }

    .button:hover {
      background-color: #45a049;
    }
  </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data3 = google.visualization.arrayToDataTable([
            ['Species', 'Sepal Length', 'Sepal Width'],
            ['setosa', {{ avgl1 }}, {{ avgw1 }}],
            ['versicolor', {{ avgl2 }}, {{ avgw2 }}],
            ['virginica', {{ avgl3 }}, {{ avgw3 }}]
          ]);

          var options3 = {
            title: 'Species vs its Sepal Attributes',
            curveType: 'function',
            legend: { position: 'bottom' }
          };

          var chart3 = new google.visualization.LineChart(document.getElementById('curve_chart'));
          chart3.draw(data3, options3);
        }
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#nextPageBtn').click(function() {
            window.location.href = "{{ url_for('next_page') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });

        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="curve_chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="nextPageBtn" class="button">Next Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3)





@app.route('/graph4')
def graph4():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()


    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
    body {
      font-family: Arial, sans-serif;
      background-color: #f1f1f1;
      margin: 0;
      padding: 0;
    }
    
    
    
    
    
    
    ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
        }

        ul.graph-menu li {
            float: left;
        }

        ul.graph-menu li a {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            text-decoration: none;
            transition: background-color 0.3s;
        }

        ul.graph-menu li a:hover {
            background-color: #f1f1f1;
        }

        ul.graph-menu li a.active {
            background-color: #4CAF50;
            color: white;
        }
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    .container {
      max-width: 100%;
      margin: 0 auto;
      padding: 20px;
    }

    h1 {
      color: #333;
      font-size: 24px;
      text-align: center;
      margin-bottom: 30px;
    }

    .charts-container {
      display: flex;
      flex-wrap: wrap;
      justify-content: center;
      align-items: flex-start;
      margin-top: 50px;
    }

    .chart {
      width: 100%;
      max-width: 500px;
      height: 400px;
      margin: 10px;
    }

    .buttons-container {
      display: flex;
      justify-content: center;
      margin-top: 20px;
      flex-wrap: wrap;
    }

    .button {
      background-color: #4CAF50;
      color: #fff;
      border: none;
      padding: 10px 20px;
      font-size: 16px;
      cursor: pointer;
      margin: 5px;
    }

    .button:hover {
      background-color: #45a049;
    }
  </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data4 = google.visualization.arrayToDataTable([
            ['Species', 'Petal Length'],
            ['setosa', {{m1}}],
            ['versicolor', {{m2}}],
            ['virginica', {{m3}}]
          ]);

          var options4 = {
            title: 'Species vs Petal Length',
            vAxis: { title: 'Petal Length' },
            legend: { position: 'none' }
          };

          var chart4 = new google.visualization.ColumnChart(document.getElementById('column_chart'));
          chart4.draw(data4, options4);
    }
    
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#nextPageBtn').click(function() {
            window.location.href = "{{ url_for('next_page') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="column_chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Previous Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)


@app.route('/graph5')
def graph5():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()


    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
    body {
      font-family: Arial, sans-serif;
      background-color: #f1f1f1;
      margin: 0;
      padding: 0;
    }
    
    
    
    
    
    
    ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
        }

        ul.graph-menu li {
            float: left;
        }

        ul.graph-menu li a {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            text-decoration: none;
            transition: background-color 0.3s;
        }

        ul.graph-menu li a:hover {
            background-color: #f1f1f1;
        }

        ul.graph-menu li a.active {
            background-color: #4CAF50;
            color: white;
        }
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    .container {
      max-width: 100%;
      margin: 0 auto;
      padding: 20px;
    }

    h1 {
      color: #333;
      font-size: 24px;
      text-align: center;
      margin-bottom: 30px;
    }

    .charts-container {
      display: flex;
      flex-wrap: wrap;
      justify-content: center;
      align-items: flex-start;
      margin-top: 50px;
    }

    .chart {
      width: 100%;
      max-width: 500px;
      height: 400px;
      margin: 10px;
    }

    .buttons-container {
      display: flex;
      justify-content: center;
      margin-top: 20px;
      flex-wrap: wrap;
    }

    .button {
      background-color: #4CAF50;
      color: #fff;
      border: none;
      padding: 10px 20px;
      font-size: 16px;
      cursor: pointer;
      margin: 5px;
    }

    .button:hover {
      background-color: #45a049;
    }
  </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data = new google.visualization.DataTable();
          data.addColumn('number', 'X');
          data.addColumn('number', 'Y');

          // Populate the data rows from the fetched data
          var rows = [
    '''

    for row in rows:
        html_code += "        [{}],\n".format(','.join(str(value) for value in row))

    html_code += '''
    ];

          data.addRows(rows);

          var options = {
              title: 'Scatter Plot',
              hAxis: {title: 'Petal_Length'},
              vAxis: {title: 'Sepal_Length'},
              legend: 'none'
          };

          var chart = new google.visualization.ScatterChart(document.getElementById('chart_div1'));
          chart.draw(data, options);
    }
    
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#nextPageBtn').click(function() {
            window.location.href = "{{ url_for('next_page') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="chart_div1" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Previous Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)



@app.route('/graph6')
def graph6():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()


    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
    body {
      font-family: Arial, sans-serif;
      background-color: #f1f1f1;
      margin: 0;
      padding: 0;
    }
    
    
    
    
    
    
    ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
        }

        ul.graph-menu li {
            float: left;
        }

        ul.graph-menu li a {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            text-decoration: none;
            transition: background-color 0.3s;
        }

        ul.graph-menu li a:hover {
            background-color: #f1f1f1;
        }

        ul.graph-menu li a.active {
            background-color: #4CAF50;
            color: white;
        }
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    .container {
      max-width: 100%;
      margin: 0 auto;
      padding: 20px;
    }

    h1 {
      color: #333;
      font-size: 24px;
      text-align: center;
      margin-bottom: 30px;
    }

    .charts-container {
      display: flex;
      flex-wrap: wrap;
      justify-content: center;
      align-items: flex-start;
      margin-top: 50px;
    }

    .chart {
      width: 100%;
      max-width: 500px;
      height: 400px;
      margin: 10px;
    }

    .buttons-container {
      display: flex;
      justify-content: center;
      margin-top: 20px;
      flex-wrap: wrap;
    }

    .button {
      background-color: #4CAF50;
      color: #fff;
      border: none;
      padding: 10px 20px;
      font-size: 16px;
      cursor: pointer;
      margin: 5px;
    }

    .button:hover {
      background-color: #45a049;
    }
  </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data6 = google.visualization.arrayToDataTable([
        ['Species', 'Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width'],
        ['Setosa', 5.1, 3.5, 1.4, 0.2],
        ['Setosa', 4.9, 3.0, 1.4, 0.2],
        ['Setosa', 4.7, 3.2, 1.3, 0.2],
        ['Versicolor', 7.0, 3.2, 4.7, 1.4],
        ['Versicolor', 6.4, 3.2, 4.5, 1.5],
        ['Versicolor', 6.9, 3.1, 4.9, 1.5],
        ['Virginica', 6.3, 3.3, 6.0, 2.5],
        ['Virginica', 5.8, 2.7, 5.1, 1.9],
        ['Virginica', 7.1, 3.0, 5.9, 2.1]
      ]);

      var options6 = {
        title: 'Iris Dataset: Sepal Length vs Sepal Width',
        hAxis: { title: 'Sepal Length' },
        vAxis: { title: 'Sepal Width' },
        bubble: { textStyle: { fontSize: 11 } }
      };

      var chart = new google.visualization.BubbleChart(document.getElementById('chart'));
      chart.draw(data6, options6);
    }
    
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#nextPageBtn').click(function() {
            window.location.href = "{{ url_for('next_page') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Previous Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)








if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template_string, redirect, url_for
import psycopg2

app = Flask(__name__)

@app.route('/')
def home():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>


      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data1 = google.visualization.arrayToDataTable([
            ['Species', 'Count'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options1 = {
            title: 'Species 1',
            pieHole: 0.4,
          };

          var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);

          var data2 = google.visualization.arrayToDataTable([
            ['Category', 'Value'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options2 = {
            title: 'My Bar Chart'
          };

          var chart2 = new google.visualization.BarChart(document.getElementById('chart_div'));
          chart2.draw(data2, options2);

          var data3 = google.visualization.arrayToDataTable([
            ['Species', 'Sepal Length', 'Sepal Width'],
            ['setosa', {{ avgl1 }}, {{ avgw1 }}],
            ['versicolor', {{ avgl2 }}, {{ avgw2 }}],
            ['virginica', {{ avgl3 }}, {{ avgw3 }}]
          ]);

          var options3 = {
            title: 'Species vs its Sepal Attributes',
            curveType: 'function',
            legend: { position: 'bottom' }
          };

          var chart3 = new google.visualization.LineChart(document.getElementById('curve_chart'));
          chart3.draw(data3, options3);
        }
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#nextPageBtn').click(function() {
            window.location.href = "{{ url_for('next_page') }}";
          });

          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="donutchart1" class="chart"></div>
          <div id="chart_div" class="chart"></div>
          <div id="curve_chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="nextPageBtn" class="button">Next Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3)

@app.route('/next_page')
def next_page():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
        <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data4 = google.visualization.arrayToDataTable([
            ['Species', 'Petal Length'],
            ['setosa', {{m1}}],
            ['versicolor', {{m2}}],
            ['virginica', {{m3}}]
          ]);

          var options4 = {
            title: 'Species vs Petal Length',
            vAxis: { title: 'Petal Length' },
            legend: { position: 'none' }
          };

          var chart4 = new google.visualization.ColumnChart(document.getElementById('column_chart'));
          chart4.draw(data4, options4);

          var data = new google.visualization.DataTable();
          data.addColumn('number', 'X');
          data.addColumn('number', 'Y');

          // Populate the data rows from the fetched data
          var rows = [
    '''

    for row in rows:
        html_code += "        [{}],\n".format(','.join(str(value) for value in row))

    html_code += '''
    ];

          data.addRows(rows);

          var options = {
              title: 'Scatter Plot',
              hAxis: {title: 'Petal_Length'},
              vAxis: {title: 'Sepal_Length'},
              legend: 'none'
          };

          var chart = new google.visualization.ScatterChart(document.getElementById('chart_div1'));
          chart.draw(data, options);
        
        var data6 = google.visualization.arrayToDataTable([
        ['Species', 'Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width'],
        ['Setosa', 5.1, 3.5, 1.4, 0.2],
        ['Setosa', 4.9, 3.0, 1.4, 0.2],
        ['Setosa', 4.7, 3.2, 1.3, 0.2],
        ['Versicolor', 7.0, 3.2, 4.7, 1.4],
        ['Versicolor', 6.4, 3.2, 4.5, 1.5],
        ['Versicolor', 6.9, 3.1, 4.9, 1.5],
        ['Virginica', 6.3, 3.3, 6.0, 2.5],
        ['Virginica', 5.8, 2.7, 5.1, 1.9],
        ['Virginica', 7.1, 3.0, 5.9, 2.1]
      ]);

      var options6 = {
        title: 'Iris Dataset: Sepal Length vs Sepal Width',
        hAxis: { title: 'Sepal Length' },
        vAxis: { title: 'Sepal Width' },
        bubble: { textStyle: { fontSize: 11 } }
      };

      var chart = new google.visualization.BubbleChart(document.getElementById('chart'));
      chart.draw(data6, options6);
    }

    
        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the previous page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
  
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="column_chart" class="chart"></div>
          <div id="chart" class="chart"></div>
          <div id="chart_div1" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Previous Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)

























@app.route('/graph1')
def graph1():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data1 = google.visualization.arrayToDataTable([
            ['Species', 'Count'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options1 = {
            title: 'Species 1',
            pieHole: 0.4,
          };

          var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);
    }
    
    
    
    

 
    
    
    
    
    
        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the previous page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="donutchart1" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Home Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)




@app.route('/graph2')
def graph2():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {

          var data2 = google.visualization.arrayToDataTable([
            ['Category', 'Value'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options2 = {
            title: 'My Bar Chart'
          };

          var chart2 = new google.visualization.BarChart(document.getElementById('chart_div'));
          chart2.draw(data2, options2);
        }
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the Home on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="chart_div" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Home Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3)





@app.route('/graph3')
def graph3():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data3 = google.visualization.arrayToDataTable([
            ['Species', 'Sepal Length', 'Sepal Width'],
            ['setosa', {{ avgl1 }}, {{ avgw1 }}],
            ['versicolor', {{ avgl2 }}, {{ avgw2 }}],
            ['virginica', {{ avgl3 }}, {{ avgw3 }}]
          ]);

          var options3 = {
            title: 'Species vs its Sepal Attributes',
            curveType: 'function',
            legend: { position: 'bottom' }
          };

          var chart3 = new google.visualization.LineChart(document.getElementById('curve_chart'));
          chart3.draw(data3, options3);
        }
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });

        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="curve_chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Home Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3)





@app.route('/graph4')
def graph4():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()


    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data4 = google.visualization.arrayToDataTable([
            ['Species', 'Petal Length'],
            ['setosa', {{m1}}],
            ['versicolor', {{m2}}],
            ['virginica', {{m3}}]
          ]);

          var options4 = {
            title: 'Species vs Petal Length',
            vAxis: { title: 'Petal Length' },
            legend: { position: 'none' }
          };

          var chart4 = new google.visualization.ColumnChart(document.getElementById('column_chart'));
          chart4.draw(data4, options4);
    }
    
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="column_chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Home Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)


@app.route('/graph5')
def graph5():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()


    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data = new google.visualization.DataTable();
          data.addColumn('number', 'X');
          data.addColumn('number', 'Y');

          // Populate the data rows from the fetched data
          var rows = [
    '''

    for row in rows:
        html_code += "        [{}],\n".format(','.join(str(value) for value in row))

    html_code += '''
    ];

          data.addRows(rows);

          var options = {
              title: 'Scatter Plot',
              hAxis: {title: 'Petal_Length'},
              vAxis: {title: 'Sepal_Length'},
              legend: 'none'
          };

          var chart = new google.visualization.ScatterChart(document.getElementById('chart_div1'));
          chart.draw(data, options);
    }
    
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="chart_div1" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Home Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)



@app.route('/graph6')
def graph6():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()


    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data6 = google.visualization.arrayToDataTable([
        ['Species', 'Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width'],
        ['Setosa', 5.1, 3.5, 1.4, 0.2],
        ['Setosa', 4.9, 3.0, 1.4, 0.2],
        ['Setosa', 4.7, 3.2, 1.3, 0.2],
        ['Versicolor', 7.0, 3.2, 4.7, 1.4],
        ['Versicolor', 6.4, 3.2, 4.5, 1.5],
        ['Versicolor', 6.9, 3.1, 4.9, 1.5],
        ['Virginica', 6.3, 3.3, 6.0, 2.5],
        ['Virginica', 5.8, 2.7, 5.1, 1.9],
        ['Virginica', 7.1, 3.0, 5.9, 2.1]
      ]);

      var options6 = {
        title: 'Iris Dataset: Sepal Length vs Sepal Width',
        hAxis: { title: 'Sepal Length' },
        vAxis: { title: 'Sepal Width' },
        bubble: { textStyle: { fontSize: 11 } }
      };

      var chart = new google.visualization.BubbleChart(document.getElementById('chart'));
      chart.draw(data6, options6);
    }
    
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#c7d6eb');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Change Background Color</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Home Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)








if __name__ == '__main__':
    app.run()

# %% [markdown]
# <h1>ENHANCING CODE</h1>

# %%
from flask import Flask, render_template_string, redirect, url_for
import psycopg2

app = Flask(__name__)

@app.route('/')
def home():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>


      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data1 = google.visualization.arrayToDataTable([
            ['Species', 'Count'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options1 = {
            title: 'Species 1',
            pieHole: 0.4,
          };

          var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);

          var data2 = google.visualization.arrayToDataTable([
            ['Category', 'Value'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options2 = {
            title: 'My Bar Chart'
          };

          var chart2 = new google.visualization.BarChart(document.getElementById('chart_div'));
          chart2.draw(data2, options2);

          var data3 = google.visualization.arrayToDataTable([
            ['Species', 'Sepal Length', 'Sepal Width'],
            ['setosa', {{ avgl1 }}, {{ avgw1 }}],
            ['versicolor', {{ avgl2 }}, {{ avgw2 }}],
            ['virginica', {{ avgl3 }}, {{ avgw3 }}]
          ]);

          var options3 = {
            title: 'Species vs its Sepal Attributes',
            curveType: 'function',
            legend: { position: 'bottom' }
          };

          var chart3 = new google.visualization.LineChart(document.getElementById('curve_chart'));
          chart3.draw(data3, options3);
        }
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#191919');
            $('h1').css('color', '#ECDBBA');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#nextPageBtn').click(function() {
            window.location.href = "{{ url_for('next_page') }}";
          });

          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="donutchart1" class="chart"></div>
          <div id="chart_div" class="chart"></div>
          <div id="curve_chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Dark Theme</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="nextPageBtn" class="button">Next Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3)

@app.route('/next_page')
def next_page():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
        <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data4 = google.visualization.arrayToDataTable([
            ['Species', 'Petal Length'],
            ['setosa', {{m1}}],
            ['versicolor', {{m2}}],
            ['virginica', {{m3}}]
          ]);

          var options4 = {
            title: 'Species vs Petal Length',
            vAxis: { title: 'Petal Length' },
            legend: { position: 'none' }
          };

          var chart4 = new google.visualization.ColumnChart(document.getElementById('column_chart'));
          chart4.draw(data4, options4);

          var data = new google.visualization.DataTable();
          data.addColumn('number', 'X');
          data.addColumn('number', 'Y');

          // Populate the data rows from the fetched data
          var rows = [
    '''

    for row in rows:
        html_code += "        [{}],\n".format(','.join(str(value) for value in row))

    html_code += '''
    ];

          data.addRows(rows);

          var options = {
              title: 'Scatter Plot',
              hAxis: {title: 'Petal_Length'},
              vAxis: {title: 'Sepal_Length'},
              legend: 'none'
          };

          var chart = new google.visualization.ScatterChart(document.getElementById('chart_div1'));
          chart.draw(data, options);
        
        var data6 = google.visualization.arrayToDataTable([
        ['Species', 'Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width'],
        ['Setosa', 5.1, 3.5, 1.4, 0.2],
        ['Setosa', 4.9, 3.0, 1.4, 0.2],
        ['Setosa', 4.7, 3.2, 1.3, 0.2],
        ['Versicolor', 7.0, 3.2, 4.7, 1.4],
        ['Versicolor', 6.4, 3.2, 4.5, 1.5],
        ['Versicolor', 6.9, 3.1, 4.9, 1.5],
        ['Virginica', 6.3, 3.3, 6.0, 2.5],
        ['Virginica', 5.8, 2.7, 5.1, 1.9],
        ['Virginica', 7.1, 3.0, 5.9, 2.1]
      ]);

      var options6 = {
        title: 'Iris Dataset: Sepal Length vs Sepal Width',
        hAxis: { title: 'Sepal Length' },
        vAxis: { title: 'Sepal Width' },
        bubble: { textStyle: { fontSize: 11 } }
      };

      var chart = new google.visualization.BubbleChart(document.getElementById('chart'));
      chart.draw(data6, options6);
    }

    
        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#191919');
            $('h1').css('color', '#ECDBBA');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the previous page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
  
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="column_chart" class="chart"></div>
          <div id="chart" class="chart"></div>
          <div id="chart_div1" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Dark Theme</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Previous Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)

























@app.route('/graph1')
def graph1():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data1 = google.visualization.arrayToDataTable([
            ['Species', 'Count'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options1 = {
            title: 'Species 1',
            pieHole: 0.4,
          };

          var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);
    }
    
    
    
    

 
    
    
    
    
    
        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#191919');
            $('h1').css('color', '#ECDBBA');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the previous page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="donutchart1" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Dark Theme</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Home Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)




@app.route('/graph2')
def graph2():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {

          var data2 = google.visualization.arrayToDataTable([
            ['Category', 'Value'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options2 = {
            title: 'My Bar Chart'
          };

          var chart2 = new google.visualization.BarChart(document.getElementById('chart_div'));
          chart2.draw(data2, options2);
        }
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#191919');
            $('h1').css('color', '#ECDBBA');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the Home on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="chart_div" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Dark Theme</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Home Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3)





@app.route('/graph3')
def graph3():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data3 = google.visualization.arrayToDataTable([
            ['Species', 'Sepal Length', 'Sepal Width'],
            ['setosa', {{ avgl1 }}, {{ avgw1 }}],
            ['versicolor', {{ avgl2 }}, {{ avgw2 }}],
            ['virginica', {{ avgl3 }}, {{ avgw3 }}]
          ]);

          var options3 = {
            title: 'Species vs its Sepal Attributes',
            curveType: 'function',
            legend: { position: 'bottom' }
          };

          var chart3 = new google.visualization.LineChart(document.getElementById('curve_chart'));
          chart3.draw(data3, options3);
        }
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#191919');
            $('h1').css('color', '#ECDBBA');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });

        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="curve_chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Dark Theme</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Home Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3)





@app.route('/graph4')
def graph4():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()


    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data4 = google.visualization.arrayToDataTable([
            ['Species', 'Petal Length'],
            ['setosa', {{m1}}],
            ['versicolor', {{m2}}],
            ['virginica', {{m3}}]
          ]);

          var options4 = {
            title: 'Species vs Petal Length',
            vAxis: { title: 'Petal Length' },
            legend: { position: 'none' }
          };

          var chart4 = new google.visualization.ColumnChart(document.getElementById('column_chart'));
          chart4.draw(data4, options4);
    }
    
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#191919');
            $('h1').css('color', '#ECDBBA');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="column_chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Dark Theme</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Home Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)


@app.route('/graph5')
def graph5():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()


    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data = new google.visualization.DataTable();
          data.addColumn('number', 'X');
          data.addColumn('number', 'Y');

          // Populate the data rows from the fetched data
          var rows = [
    '''

    for row in rows:
        html_code += "        [{}],\n".format(','.join(str(value) for value in row))

    html_code += '''
    ];

          data.addRows(rows);

          var options = {
              title: 'Scatter Plot',
              hAxis: {title: 'Petal_Length'},
              vAxis: {title: 'Sepal_Length'},
              legend: 'none'
          };

          var chart = new google.visualization.ScatterChart(document.getElementById('chart_div1'));
          chart.draw(data, options);
    }
    
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#191919');
            $('h1').css('color', '#ECDBBA');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="chart_div1" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Dark Theme</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Home Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)



@app.route('/graph6')
def graph6():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()


    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data6 = google.visualization.arrayToDataTable([
        ['Species', 'Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width'],
        ['Setosa', 5.1, 3.5, 1.4, 0.2],
        ['Setosa', 4.9, 3.0, 1.4, 0.2],
        ['Setosa', 4.7, 3.2, 1.3, 0.2],
        ['Versicolor', 7.0, 3.2, 4.7, 1.4],
        ['Versicolor', 6.4, 3.2, 4.5, 1.5],
        ['Versicolor', 6.9, 3.1, 4.9, 1.5],
        ['Virginica', 6.3, 3.3, 6.0, 2.5],
        ['Virginica', 5.8, 2.7, 5.1, 1.9],
        ['Virginica', 7.1, 3.0, 5.9, 2.1]
      ]);

      var options6 = {
        title: 'Iris Dataset: Sepal Length vs Sepal Width',
        hAxis: { title: 'Sepal Length' },
        vAxis: { title: 'Sepal Width' },
        bubble: { textStyle: { fontSize: 11 } }
      };

      var chart = new google.visualization.BubbleChart(document.getElementById('chart'));
      chart.draw(data6, options6);
    }
    
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#191919');
            $('h1').css('color', '#ECDBBA');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Dark Theme</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Home Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)








if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template_string, redirect, url_for
import psycopg2

app = Flask(__name__)

@app.route('/')
def home():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>


      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data1 = google.visualization.arrayToDataTable([
            ['Species', 'Count'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options1 = {
            title: 'Species 1',
            pieHole: 0.4,
          };

          var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);

          var data2 = google.visualization.arrayToDataTable([
            ['Category', 'Value'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options2 = {
            title: 'My Bar Chart'
          };

          var chart2 = new google.visualization.BarChart(document.getElementById('chart_div'));
          chart2.draw(data2, options2);

          var data3 = google.visualization.arrayToDataTable([
            ['Species', 'Sepal Length', 'Sepal Width'],
            ['setosa', {{ avgl1 }}, {{ avgw1 }}],
            ['versicolor', {{ avgl2 }}, {{ avgw2 }}],
            ['virginica', {{ avgl3 }}, {{ avgw3 }}]
          ]);

          var options3 = {
            title: 'Species vs its Sepal Attributes',
            curveType: 'function',
            legend: { position: 'bottom' }
          };

          var chart3 = new google.visualization.LineChart(document.getElementById('curve_chart'));
          chart3.draw(data3, options3);
        }
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#191919');
            $('h1').css('color', '#ECDBBA');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#nextPageBtn').click(function() {
            window.location.href = "{{ url_for('next_page') }}";
          });

          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="donutchart1" class="chart"></div>
          <div id="chart_div" class="chart"></div>
          <div id="curve_chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Dark Theme</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="nextPageBtn" class="button">Next Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3)

@app.route('/next_page')
def next_page():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
        <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data4 = google.visualization.arrayToDataTable([
            ['Species', 'Petal Length'],
            ['setosa', {{m1}}],
            ['versicolor', {{m2}}],
            ['virginica', {{m3}}]
          ]);

          var options4 = {
            title: 'Species vs Petal Length',
            vAxis: { title: 'Petal Length' },
            legend: { position: 'none' }
          };

          var chart4 = new google.visualization.ColumnChart(document.getElementById('column_chart'));
          chart4.draw(data4, options4);

          var data = new google.visualization.DataTable();
          data.addColumn('number', 'X');
          data.addColumn('number', 'Y');

          // Populate the data rows from the fetched data
          var rows = [
    '''

    for row in rows:
        html_code += "        [{}],\n".format(','.join(str(value) for value in row))

    html_code += '''
    ];

          data.addRows(rows);

          var options = {
              title: 'Scatter Plot',
              hAxis: {title: 'Petal_Length'},
              vAxis: {title: 'Sepal_Length'},
              legend: 'none'
          };

          var chart = new google.visualization.ScatterChart(document.getElementById('chart_div1'));
          chart.draw(data, options);
        
        var data6 = google.visualization.arrayToDataTable([
        ['Species', 'Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width'],
        ['Setosa', 5.1, 3.5, 1.4, 0.2],
        ['Setosa', 4.9, 3.0, 1.4, 0.2],
        ['Setosa', 4.7, 3.2, 1.3, 0.2],
        ['Versicolor', 7.0, 3.2, 4.7, 1.4],
        ['Versicolor', 6.4, 3.2, 4.5, 1.5],
        ['Versicolor', 6.9, 3.1, 4.9, 1.5],
        ['Virginica', 6.3, 3.3, 6.0, 2.5],
        ['Virginica', 5.8, 2.7, 5.1, 1.9],
        ['Virginica', 7.1, 3.0, 5.9, 2.1]
      ]);

      var options6 = {
        title: 'Iris Dataset: Sepal Length vs Sepal Width',
        hAxis: { title: 'Sepal Length' },
        vAxis: { title: 'Sepal Width' },
        bubble: { textStyle: { fontSize: 11 } }
      };

      var chart = new google.visualization.BubbleChart(document.getElementById('chart'));
      chart.draw(data6, options6);
    }

    
        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#191919');
            $('h1').css('color', '#ECDBBA');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the previous page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
  
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="column_chart" class="chart"></div>
          <div id="chart" class="chart"></div>
          <div id="chart_div1" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Dark Theme</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Previous Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)

























@app.route('/graph1')
def graph1():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data1 = google.visualization.arrayToDataTable([
            ['Species', 'Count'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options1 = {
            title: 'Species 1',
            pieHole: 0.4,
          };

          var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);
    }
    
    
    
    

 
    
    
    
    
    
        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#191919');
            $('h1').css('color', '#ECDBBA');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the previous page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="donutchart1" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Dark Theme</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Home Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)




@app.route('/graph2')
def graph2():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {

          var data2 = google.visualization.arrayToDataTable([
            ['Category', 'Value'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options2 = {
            title: 'My Bar Chart'
          };

          var chart2 = new google.visualization.BarChart(document.getElementById('chart_div'));
          chart2.draw(data2, options2);
        }
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#191919');
            $('h1').css('color', '#ECDBBA');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the Home on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="chart_div" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Dark Theme</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Home Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3)





@app.route('/graph3')
def graph3():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data3 = google.visualization.arrayToDataTable([
            ['Species', 'Sepal Length', 'Sepal Width'],
            ['setosa', {{ avgl1 }}, {{ avgw1 }}],
            ['versicolor', {{ avgl2 }}, {{ avgw2 }}],
            ['virginica', {{ avgl3 }}, {{ avgw3 }}]
          ]);

          var options3 = {
            title: 'Species vs its Sepal Attributes',
            curveType: 'function',
            legend: { position: 'bottom' }
          };

          var chart3 = new google.visualization.LineChart(document.getElementById('curve_chart'));
          chart3.draw(data3, options3);
        }
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#191919');
            $('h1').css('color', '#ECDBBA');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });

        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="curve_chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Dark Theme</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Home Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3)





@app.route('/graph4')
def graph4():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()


    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data4 = google.visualization.arrayToDataTable([
            ['Species', 'Petal Length'],
            ['setosa', {{m1}}],
            ['versicolor', {{m2}}],
            ['virginica', {{m3}}]
          ]);

          var options4 = {
            title: 'Species vs Petal Length',
            vAxis: { title: 'Petal Length' },
            legend: { position: 'none' }
          };

          var chart4 = new google.visualization.ColumnChart(document.getElementById('column_chart'));
          chart4.draw(data4, options4);
    }
    
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#191919');
            $('h1').css('color', '#ECDBBA');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="column_chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Dark Theme</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Home Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)


@app.route('/graph5')
def graph5():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()


    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data = new google.visualization.DataTable();
          data.addColumn('number', 'X');
          data.addColumn('number', 'Y');

          // Populate the data rows from the fetched data
          var rows = [
    '''

    for row in rows:
        html_code += "        [{}],\n".format(','.join(str(value) for value in row))

    html_code += '''
    ];

          data.addRows(rows);

          var options = {
              title: 'Scatter Plot',
              hAxis: {title: 'Petal_Length'},
              vAxis: {title: 'Sepal_Length'},
              legend: 'none'
          };

          var chart = new google.visualization.ScatterChart(document.getElementById('chart_div1'));
          chart.draw(data, options);
    }
    
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#191919');
            $('h1').css('color', '#ECDBBA');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="chart_div1" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Dark Theme</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Home Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)



@app.route('/graph6')
def graph6():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()


    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data6 = google.visualization.arrayToDataTable([
        ['Species', 'Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width'],
        ['Setosa', 5.1, 3.5, 1.4, 0.2],
        ['Setosa', 4.9, 3.0, 1.4, 0.2],
        ['Setosa', 4.7, 3.2, 1.3, 0.2],
        ['Versicolor', 7.0, 3.2, 4.7, 1.4],
        ['Versicolor', 6.4, 3.2, 4.5, 1.5],
        ['Versicolor', 6.9, 3.1, 4.9, 1.5],
        ['Virginica', 6.3, 3.3, 6.0, 2.5],
        ['Virginica', 5.8, 2.7, 5.1, 1.9],
        ['Virginica', 7.1, 3.0, 5.9, 2.1]
      ]);

      var options6 = {
        title: 'Iris Dataset: Sepal Length vs Sepal Width',
        hAxis: { title: 'Sepal Length' },
        vAxis: { title: 'Sepal Width' },
        bubble: { textStyle: { fontSize: 11 } }
      };

      var chart = new google.visualization.BubbleChart(document.getElementById('chart'));
      chart.draw(data6, options6);
    }
    
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#191919');
            $('h1').css('color', '#ECDBBA');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Dark Theme</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Home Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)








if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template_string, redirect, url_for
import psycopg2

app = Flask(__name__)

@app.route('/')
def home():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>


      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data1 = google.visualization.arrayToDataTable([
            ['Species', 'Count'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options1 = {
            title: 'Species 1',
            pieHole: 0.4,
          };

          var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);

          var data2 = google.visualization.arrayToDataTable([
            ['Category', 'Value'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options2 = {
            title: 'My Bar Chart'
          };

          var chart2 = new google.visualization.BarChart(document.getElementById('chart_div'));
          chart2.draw(data2, options2);

          var data3 = google.visualization.arrayToDataTable([
            ['Species', 'Sepal Length', 'Sepal Width'],
            ['setosa', {{ avgl1 }}, {{ avgw1 }}],
            ['versicolor', {{ avgl2 }}, {{ avgw2 }}],
            ['virginica', {{ avgl3 }}, {{ avgw3 }}]
          ]);

          var options3 = {
            title: 'Species vs its Sepal Attributes',
            curveType: 'function',
            legend: { position: 'bottom' }
          };

          var chart3 = new google.visualization.LineChart(document.getElementById('curve_chart'));
          chart3.draw(data3, options3);
          
          var data6 = google.visualization.arrayToDataTable([
        ['Species', 'Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width'],
        ['Setosa', 5.1, 3.5, 1.4, 0.2],
        ['Setosa', 4.9, 3.0, 1.4, 0.2],
        ['Setosa', 4.7, 3.2, 1.3, 0.2],
        ['Versicolor', 7.0, 3.2, 4.7, 1.4],
        ['Versicolor', 6.4, 3.2, 4.5, 1.5],
        ['Versicolor', 6.9, 3.1, 4.9, 1.5],
        ['Virginica', 6.3, 3.3, 6.0, 2.5],
        ['Virginica', 5.8, 2.7, 5.1, 1.9],
        ['Virginica', 7.1, 3.0, 5.9, 2.1]
      ]);

      var options6 = {
        title: 'Iris Dataset: Sepal Length vs Sepal Width',
        hAxis: { title: 'Sepal Length' },
        vAxis: { title: 'Sepal Width' },
        bubble: { textStyle: { fontSize: 11 } }
      };

      var chart = new google.visualization.BubbleChart(document.getElementById('chart'));
      chart.draw(data6, options6);
        }
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#191919');
            $('h1').css('color', '#ECDBBA');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#nextPageBtn').click(function() {
            window.location.href = "{{ url_for('next_page') }}";
          });

          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="donutchart1" class="chart"></div>
          <div id="chart_div" class="chart"></div>
          <div id="curve_chart" class="chart"></div>
          <div id="chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Dark Theme</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="nextPageBtn" class="button">Next Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3)

@app.route('/next_page')
def next_page():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
        <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data4 = google.visualization.arrayToDataTable([
            ['Species', 'Petal Length'],
            ['setosa', {{m1}}],
            ['versicolor', {{m2}}],
            ['virginica', {{m3}}]
          ]);

          var options4 = {
            title: 'Species vs Petal Length',
            vAxis: { title: 'Petal Length' },
            legend: { position: 'none' }
          };

          var chart4 = new google.visualization.ColumnChart(document.getElementById('column_chart'));
          chart4.draw(data4, options4);

          var data = new google.visualization.DataTable();
          data.addColumn('number', 'X');
          data.addColumn('number', 'Y');

          // Populate the data rows from the fetched data
          var rows = [
    '''

    for row in rows:
        html_code += "        [{}],\n".format(','.join(str(value) for value in row))

    html_code += '''
    ];

          data.addRows(rows);

          var options = {
              title: 'Scatter Plot',
              hAxis: {title: 'Petal_Length'},
              vAxis: {title: 'Sepal_Length'},
              legend: 'none'
          };

          var chart = new google.visualization.ScatterChart(document.getElementById('chart_div1'));
          chart.draw(data, options);
    }

    
        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#191919');
            $('h1').css('color', '#ECDBBA');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the previous page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
  
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="column_chart" class="chart"></div>
          <div id="chart_div1" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Dark Theme</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Previous Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)

























@app.route('/graph1')
def graph1():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data1 = google.visualization.arrayToDataTable([
            ['Species', 'Count'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options1 = {
            title: 'Species 1',
            pieHole: 0.4,
          };

          var chart1 = new google.visualization.PieChart(document.getElementById('donutchart1'));
          chart1.draw(data1, options1);
    }
    
    
    
    

 
    
    
    
    
    
        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#191919');
            $('h1').css('color', '#ECDBBA');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the previous page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="donutchart1" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Dark Theme</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Home Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)




@app.route('/graph2')
def graph2():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {

          var data2 = google.visualization.arrayToDataTable([
            ['Category', 'Value'],
            ['setosa', {{ count1 }}],
            ['versicolor', {{ count2 }}],
            ['virginica', {{ count3 }}]
          ]);

          var options2 = {
            title: 'My Bar Chart'
          };

          var chart2 = new google.visualization.BarChart(document.getElementById('chart_div'));
          chart2.draw(data2, options2);
        }
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#191919');
            $('h1').css('color', '#ECDBBA');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the Home on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="chart_div" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Dark Theme</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Home Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3)





@app.route('/graph3')
def graph3():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    # Close the cursor and database connection
    cursor.close()
    conn.close()

    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data3 = google.visualization.arrayToDataTable([
            ['Species', 'Sepal Length', 'Sepal Width'],
            ['setosa', {{ avgl1 }}, {{ avgw1 }}],
            ['versicolor', {{ avgl2 }}, {{ avgw2 }}],
            ['virginica', {{ avgl3 }}, {{ avgw3 }}]
          ]);

          var options3 = {
            title: 'Species vs its Sepal Attributes',
            curveType: 'function',
            legend: { position: 'bottom' }
          };

          var chart3 = new google.visualization.LineChart(document.getElementById('curve_chart'));
          chart3.draw(data3, options3);
        }
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#191919');
            $('h1').css('color', '#ECDBBA');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });

        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Chart Dashboard</h1>
        <div class="charts-container">
          <div id="curve_chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Dark Theme</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Home Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3)





@app.route('/graph4')
def graph4():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()


    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data4 = google.visualization.arrayToDataTable([
            ['Species', 'Petal Length'],
            ['setosa', {{m1}}],
            ['versicolor', {{m2}}],
            ['virginica', {{m3}}]
          ]);

          var options4 = {
            title: 'Species vs Petal Length',
            vAxis: { title: 'Petal Length' },
            legend: { position: 'none' }
          };

          var chart4 = new google.visualization.ColumnChart(document.getElementById('column_chart'));
          chart4.draw(data4, options4);
    }
    
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#191919');
            $('h1').css('color', '#ECDBBA');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="column_chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Dark Theme</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Home Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)


@app.route('/graph5')
def graph5():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()


    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data = new google.visualization.DataTable();
          data.addColumn('number', 'X');
          data.addColumn('number', 'Y');

          // Populate the data rows from the fetched data
          var rows = [
    '''

    for row in rows:
        html_code += "        [{}],\n".format(','.join(str(value) for value in row))

    html_code += '''
    ];

          data.addRows(rows);

          var options = {
              title: 'Scatter Plot',
              hAxis: {title: 'Petal_Length'},
              vAxis: {title: 'Sepal_Length'},
              legend: 'none'
          };

          var chart = new google.visualization.ScatterChart(document.getElementById('chart_div1'));
          chart.draw(data, options);
    }
    
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#191919');
            $('h1').css('color', '#ECDBBA');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="chart_div1" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Dark Theme</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Home Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)



@app.route('/graph6')
def graph6():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        database="NewDB",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )

    # Create a cursor object to interact with the database
    cursor = conn.cursor()

    # Execute SQL queries to fetch the data from the iris table
    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='setosa';")
    rows1 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='versicolor';")
    rows2 = cursor.fetchone()

    cursor.execute("SELECT COUNT(species) FROM iris WHERE species='virginica';")
    rows3 = cursor.fetchone()

    count1 = rows1[0]
    count2 = rows2[0]
    count3 = rows3[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT AVG(sepallength) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='setosa';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='versicolor';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT AVG(sepalwidth) FROM iris WHERE species='virginica';")
    avg = cursor.fetchone()
    avgw3 = avg[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='setosa';")
    ma = cursor.fetchone()
    m1 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='versicolor';")
    ma = cursor.fetchone()
    m2 = ma[0]
    
    
    cursor.execute("SELECT MAX(petallength) FROM iris WHERE species='virginica';")
    ma = cursor.fetchone()
    m3 = ma[0]
    
    query5 = 'SELECT petallength, sepallength FROM iris'
    cursor.execute(query5)

    # Fetch all the rows from the query result
    rows = cursor.fetchall()

    # Close the cursor and database connection
    cursor.close()
    conn.close()


    html_code = '''
    <html>
    <head>
      <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
      <script src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
      <style>
          body {
            font-family: Arial, sans-serif;
            background-color: #f1f1f1;
            margin: 0;
            padding: 0;
          }

          ul.graph-menu {
            list-style-type: none;
            margin: 0;
            padding: 0;
            overflow: hidden;
            background-color: #f9f9f9;
            border-bottom: 1px solid #ccc;
            box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.1);
            font-family: Arial, sans-serif;
          }

          ul.graph-menu li {
            float: left;
          }

          ul.graph-menu li button {
            display: block;
            color: #333;
            text-align: center;
            padding: 14px 16px;
            background-color: transparent;
            border: none;
            outline: none;
            cursor: pointer;
            transition: background-color 0.3s;
          }

          ul.graph-menu li button:hover {
            background-color: #f1f1f1;
          }

          ul.graph-menu li button.active {
            background-color: #4CAF50;
            color: white;
          }

          .container {
            max-width: 100%;
            margin: 0 auto;
            padding: 20px;
          }

          h1 {
            color: #333;
            font-size: 24px;
            text-align: center;
            margin-bottom: 30px;
          }

          .charts-container {
            display: flex;
            flex-wrap: wrap;
            justify-content: center;
            align-items: flex-start;
            margin-top: 50px;
          }

          .chart {
            width: 100%;
            max-width: 500px;
            height: 400px;
            margin: 10px;
          }

          .buttons-container {
            display: flex;
            justify-content: center;
            margin-top: 20px;
            flex-wrap: wrap;
          }

          .button {
            background-color: #4CAF50;
            color: #fff;
            border: none;
            padding: 10px 20px;
            font-size: 16px;
            cursor: pointer;
            margin: 5px;
            transition: background-color 0.3s;
          }

          .button:hover {
            background-color: #45a049;
          }
    </style>

      <script type="text/javascript">
        google.charts.load("current", {packages:["corechart"]});
        google.charts.setOnLoadCallback(drawCharts);

        function drawCharts() {
          var data6 = google.visualization.arrayToDataTable([
        ['Species', 'Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width'],
        ['Setosa', 5.1, 3.5, 1.4, 0.2],
        ['Setosa', 4.9, 3.0, 1.4, 0.2],
        ['Setosa', 4.7, 3.2, 1.3, 0.2],
        ['Versicolor', 7.0, 3.2, 4.7, 1.4],
        ['Versicolor', 6.4, 3.2, 4.5, 1.5],
        ['Versicolor', 6.9, 3.1, 4.9, 1.5],
        ['Virginica', 6.3, 3.3, 6.0, 2.5],
        ['Virginica', 5.8, 2.7, 5.1, 1.9],
        ['Virginica', 7.1, 3.0, 5.9, 2.1]
      ]);

      var options6 = {
        title: 'Iris Dataset: Sepal Length vs Sepal Width',
        hAxis: { title: 'Sepal Length' },
        vAxis: { title: 'Sepal Width' },
        bubble: { textStyle: { fontSize: 11 } }
      };

      var chart = new google.visualization.BubbleChart(document.getElementById('chart'));
      chart.draw(data6, options6);
    }
    
             
        
        
        

        $(document).ready(function() {
          // Change the background color on button click
          $('#changeBgColorBtn').click(function() {
            $('body').css('background-color', '#191919');
            $('h1').css('color', '#ECDBBA');
          });

          // Change the chart title on button click
          $('#changeTitleBtn').click(function() {
            $('.chart-title').text('Updated Chart Title');
          });

          // Redirect to the next page on button click
          $('#prevPageBtn').click(function() {
            window.location.href = "{{ url_for('home') }}";
          });
          $('#graph1').click(function() {
            window.location.href = "{{ url_for('graph1') }}";
          });
          $('#graph2').click(function() {
            window.location.href = "{{ url_for('graph2') }}";
          });
          $('#graph3').click(function() {
            window.location.href = "{{ url_for('graph3') }}";
          });
          $('#graph4').click(function() {
            window.location.href = "{{ url_for('graph4') }}";
          });
          $('#graph5').click(function() {
            window.location.href = "{{ url_for('graph5') }}";
          });
          $('#graph6').click(function() {
            window.location.href = "{{ url_for('graph6') }}";
          });
        });
      </script>
    </head>
    <body>
    
    
    
    
    
    
    
    
    
    <ul class="graph-menu">
    
        <li><button id = "graph1">Graph 1</button></li>
        <li><button id = "graph2">Graph 2</button></li>
        <li><button id = "graph3">Graph 3</button></li>
        <li><button id = "graph4">Graph 4</button></li>
        <li><button id = "graph5">Graph 5</button></li>
        <li><button id = "graph6">Graph 6</button></li>
    </ul>
    
    
    
    
      <div class="container">
        <h1 class="chart-title">Iris Dataset</h1>
        <div class="charts-container">
          <div id="chart" class="chart"></div>
        </div>
        <div class="buttons-container">
          <button id="changeBgColorBtn" class="button">Dark Theme</button>
          <button id="changeTitleBtn" class="button">Change Chart Title</button>
          <button id="prevPageBtn" class="button">Home Page</button>
        </div>
      </div>
    </body>
    </html>
    '''

    return render_template_string(html_code, count1=count1, count2=count2, count3=count3, avgl1=avgl1, avgl2=avgl2, avgl3=avgl3, avgw1=avgw1, avgw2=avgw2, avgw3=avgw3, m1=m1, m2=m2, m3=m3, rows=rows)








if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
