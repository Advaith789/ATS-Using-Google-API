# %%
from flask import Flask, render_template, jsonify
import psycopg2

app = Flask(__name__)

def get_data():
    conn = psycopg2.connect(
        database="Candidate_List",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )
    cursor = conn.cursor()

    cursor.execute("SELECT COUNT(*) FROM list WHERE Marital_Status='Married';")
    rows1 = cursor.fetchone()
    married_count = rows1[0]

    cursor.execute("SELECT COUNT(*) FROM list WHERE Marital_Status='Single';")
    rows2 = cursor.fetchone()
    single_count = rows2[0]

    cursor.close()
    conn.close()

    return married_count, single_count

@app.route('/')
def home():
    return render_template('index.html')

@app.route('/get_json_data')
def get_json_data():
    married_count, single_count = get_data()
    data = {
        'Married': married_count,
        'Single': single_count
    }
    return jsonify(data)

if __name__ == '__main__':
    app.run()

# %% [markdown]
# <h1>Trying to save json</h1>

# %%
from flask import Flask, render_template, jsonify
import psycopg2
import os
import json

app = Flask(__name__)

def get_data():
    conn = psycopg2.connect(
        database="Candidate_List",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )
    cursor = conn.cursor()

    cursor.execute("SELECT COUNT(*) FROM list WHERE Marital_Status='Married';")
    rows1 = cursor.fetchone()
    married_count = rows1[0]

    cursor.execute("SELECT COUNT(*) FROM list WHERE Marital_Status='Single';")
    rows2 = cursor.fetchone()
    single_count = rows2[0]

    cursor.close()
    conn.close()

    return married_count, single_count

@app.route('/')
def home():
    return render_template('indexG1.html')

@app.route('/get_json_data')
def get_json_data():
    married_count, single_count = get_data()
    data = {
        'Married': married_count,
        'Single': single_count
    }
    
    # Save the data as a JSON file
    file_path = os.path.join('JSON File', 'data.json')
    with open(file_path, 'w') as file:
        json.dump(data, file)

    return jsonify(data)

if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template, jsonify
import psycopg2
import os
import json

app = Flask(__name__)

def get_data():
    conn = psycopg2.connect(
        database="Candidate_List",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )
    cursor = conn.cursor()

    cursor.execute("SELECT COUNT(*) FROM list WHERE Marital_Status='Married';")
    rows1 = cursor.fetchone()
    married_count = rows1[0]

    cursor.execute("SELECT COUNT(*) FROM list WHERE Marital_Status='Single';")
    rows2 = cursor.fetchone()
    single_count = rows2[0]

    cursor.close()
    conn.close()

    return married_count, single_count





def get_data2():
    conn = psycopg2.connect(
        database="Candidate_List",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )
    cursor = conn.cursor()

    cursor.execute("SELECT COUNT(gender) FROM list WHERE gender='male';")
    rows1a = cursor.fetchone()

    cursor.execute("SELECT COUNT(gender) FROM list WHERE gender='female';")
    rows2a = cursor.fetchone()

    count1a = rows1a[0]
    count2a = rows2a[0]

    cursor.close()
    conn.close()

    return count1a, count2a






@app.route('/')
def home():
    return render_template('indexG1.html')

@app.route('/get_json_data')
def get_json_data():
    married_count, single_count = get_data()
    data = {
        'Married': married_count,
        'Single': single_count
    }
    
    # Save the data as a JSON file
    file_path = os.path.join('JSON File', 'data.json')
    with open(file_path, 'w') as file:
        json.dump(data, file)

    return jsonify(data)

if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template, jsonify
import psycopg2
import os
import json

app = Flask(__name__)

def convert_to_float(data):
    if isinstance(data, dict):
        return {convert_to_float(key): convert_to_float(value) for key, value in data.items()}
    elif isinstance(data, list):
        return [convert_to_float(element) for element in data]
    elif isinstance(data, Decimal):
        return str(data)
    return data




def get_data1():
    conn = psycopg2.connect(
        database="Candidate_List",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )
    cursor = conn.cursor()

    cursor.execute("SELECT COUNT(*) FROM list WHERE Marital_Status='Married';")
    rows1 = cursor.fetchone()
    married_count = rows1[0]

    cursor.execute("SELECT COUNT(*) FROM list WHERE Marital_Status='Single';")
    rows2 = cursor.fetchone()
    single_count = rows2[0]

    cursor.close()
    conn.close()

    data = {
        "Married": married_count,
        "Single": single_count
    }
    file_path = os.path.join('JSON File', 'dataG1.json')
    with open(file_path, 'w') as file:
        json.dump(data, file)

    return convert_to_float(data)

def get_data2():
    conn = psycopg2.connect(
        database="Candidate_List",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )
    cursor = conn.cursor()

    cursor.execute("SELECT COUNT(gender) FROM list WHERE gender='male';")
    rows1a = cursor.fetchone()

    cursor.execute("SELECT COUNT(gender) FROM list WHERE gender='female';")
    rows2a = cursor.fetchone()

    count1a = rows1a[0]
    count2a = rows2a[0]

    cursor.close()
    conn.close()

    data = {
        "Male": count1a,
        "Female": count2a
    }

    file_path = os.path.join('JSON File', 'dataG2.json')
    with open(file_path, 'w') as file:
        json.dump(data, file)

    return convert_to_float(data)

def get_data3():
    conn = psycopg2.connect(
        database="Candidate_List",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )
    cursor = conn.cursor()

    cursor.execute("SELECT COUNT(Employee_Category) FROM list WHERE Employee_Category='Permanent';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT COUNT(Employee_Category) FROM list WHERE Employee_Category='Contract';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT COUNT(Employee_Category) FROM list WHERE Employee_Category='Consultant';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT COUNT(Employee_Category) FROM list WHERE Employee_Category='Probationary';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT COUNT(Employee_Category) FROM list WHERE Employee_Category='Freelancers';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT COUNT(Employee_Category) FROM list WHERE Employee_Category='Interns';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    data = {
        "Permanent": avgl1,
        "Contract": avgl2,
        "Consultant": avgl3,
        "Probationary": avgw1,
        "Freelancers": avgw2,
        "Interns": avgw3,
    }
    file_path = os.path.join('JSON File', 'dataG3.json')
    with open(file_path, 'w') as file:
        json.dump(data, file)

    return convert_to_float(data)


@app.route('/get_json_data')
def jsonAll():
    data3 = get_data3()
    data2 = get_data2()
    data1 = get_data1()

    all_data = {
        'data3': data3,
        'data2': data2,
        'data1': data1
    }

    file_path = os.path.join('JSON File', 'all_data.json')
    with open(file_path, 'w') as file:
        json.dump(all_data, file)

    return jsonify(convert_to_float(all_data))

@app.route('/')
def home():
    return render_template('indexGall.html')

if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template, jsonify
import psycopg2
import os
import json
from decimal import Decimal

app = Flask(__name__)

def convert_to_float(data):
    if isinstance(data, dict):
        return {convert_to_float(key): convert_to_float(value) for key, value in data.items()}
    elif isinstance(data, list):
        return [convert_to_float(element) for element in data]
    elif isinstance(data, Decimal):
        return str(data)
    return data


def get_data1():
    conn = psycopg2.connect(
        database="Candidate_List",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )
    cursor = conn.cursor()

    cursor.execute("SELECT COUNT(*) FROM list WHERE Marital_Status='Married';")
    rows1 = cursor.fetchone()
    married_count = rows1[0]

    cursor.execute("SELECT COUNT(*) FROM list WHERE Marital_Status='Single';")
    rows2 = cursor.fetchone()
    single_count = rows2[0]

    cursor.close()
    conn.close()

    data = {
        "Married": married_count,
        "Single": single_count
    }
    file_path = os.path.join('JSON File', 'dataG1.json')
    with open(file_path, 'w') as file:
        json.dump(data, file)

    return convert_to_float(data)


def get_data2():
    conn = psycopg2.connect(
        database="Candidate_List",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )
    cursor = conn.cursor()

    cursor.execute("SELECT COUNT(gender) FROM list WHERE gender='male';")
    rows1a = cursor.fetchone()

    cursor.execute("SELECT COUNT(gender) FROM list WHERE gender='female';")
    rows2a = cursor.fetchone()

    count1a = rows1a[0]
    count2a = rows2a[0]

    cursor.close()
    conn.close()

    data = {
        "Male": count1a,
        "Female": count2a
    }

    file_path = os.path.join('JSON File', 'dataG2.json')
    with open(file_path, 'w') as file:
        json.dump(data, file)

    return convert_to_float(data)


def get_data3():
    conn = psycopg2.connect(
        database="Candidate_List",
        user="postgres",
        password="Adduvaith789",
        host="localhost",
        port="5432"
    )
    cursor = conn.cursor()

    cursor.execute("SELECT COUNT(Employee_Category) FROM list WHERE Employee_Category='Permanent';")
    avg = cursor.fetchone()
    avgl1 = avg[0]

    cursor.execute("SELECT COUNT(Employee_Category) FROM list WHERE Employee_Category='Contract';")
    avg = cursor.fetchone()
    avgl2 = avg[0]

    cursor.execute("SELECT COUNT(Employee_Category) FROM list WHERE Employee_Category='Consultant';")
    avg = cursor.fetchone()
    avgl3 = avg[0]

    cursor.execute("SELECT COUNT(Employee_Category) FROM list WHERE Employee_Category='Probationary';")
    avg = cursor.fetchone()
    avgw1 = avg[0]

    cursor.execute("SELECT COUNT(Employee_Category) FROM list WHERE Employee_Category='Freelancers';")
    avg = cursor.fetchone()
    avgw2 = avg[0]

    cursor.execute("SELECT COUNT(Employee_Category) FROM list WHERE Employee_Category='Interns';")
    avg = cursor.fetchone()
    avgw3 = avg[0]

    data = {
        "Permanent": avgl1,
        "Contract": avgl2,
        "Consultant": avgl3,
        "Probationary": avgw1,
        "Freelancers": avgw2,
        "Interns": avgw3,
    }
    file_path = os.path.join('JSON File', 'dataG3.json')
    with open(file_path, 'w') as file:
        json.dump(data, file)

    return convert_to_float(data)


@app.route('/get_json_data')
def jsonAll():
    data3 = get_data3()
    data2 = get_data2()
    data1 = get_data1()

    all_data = {
        'data3': data3,
        'data2': data2,
        'data1': data1
    }

    file_path = os.path.join('JSON File', 'all_data.json')
    with open(file_path, 'w') as file:
        json.dump(all_data, file)

    return jsonify(convert_to_float(all_data))


@app.route('/')
def home():
    return render_template('indexGall.html')


if __name__ == '__main__':
    app.run()

# %%
from flask import Flask, render_template, jsonify
import psycopg2
import os
import json
from decimal import Decimal

app = Flask(__name__)

def convert_to_float(data):
    if isinstance(data, dict):
        return {convert_to_float(key): convert_to_float(value) for key, value in data.items()}
    elif isinstance(data, list):
        return [convert_to_float(element) for element in data]
    elif isinstance(data, Decimal):
        return str(data)
    return data


@app.route('/')
def home():
    return render_template('indexGall.html')


if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [05/Jun/2023 12:16:45] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jun/2023 12:16:45] "GET /graph1.py HTTP/1.1" 404 -
# 127.0.0.1 - - [05/Jun/2023 12:19:57] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jun/2023 12:19:57] "GET /graph1.py HTTP/1.1" 404 -
# 127.0.0.1 - - [05/Jun/2023 12:20:03] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jun/2023 12:20:03] "GET /graph1.py HTTP/1.1" 404 -
